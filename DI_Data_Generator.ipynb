# %%
import csv
import pandas as pd
import numpy as np
from sklearn.feature_selection import mutual_info_classif

# %%
def Normalize(data_array):
    max = data_array.max()
    min = data_array.min()
    new_values = []
    for i in range(len(data_array)):
        new_value = (data_array[i] - min) / (max - min)
        new_values.append(new_value)

    return new_values

# %% [markdown]
# # Adult Data Preprocess

# %%
adult_df = pd.read_csv('Datasets/Original_Datasets/original_adult.csv',header=None)
adult_df.columns = original_adult_df.columns.astype(str)

work_class_values = adult_df['1']

private = []
self_emp_not_inc = []
self_emp_inc = []
federal_gov = []
local_gov = []
state_gov = []
without_pay = []
never_worked = []

for i in range(len(work_class_values)):
    if work_class_values[i] == ' Private':
        private.append(1)
        self_emp_not_inc.append(0)
        self_emp_inc.append(0)
        federal_gov.append(0)
        local_gov.append(0)
        state_gov.append(0)
        without_pay.append(0)
        never_worked.append(0)
    elif work_class_values[i] == ' Self-emp-not-inc':
        private.append(0)
        self_emp_not_inc.append(1)
        self_emp_inc.append(0)
        federal_gov.append(0)
        local_gov.append(0)
        state_gov.append(0)
        without_pay.append(0)
        never_worked.append(0)
    elif work_class_values[i] == ' Self-emp-inc':
        private.append(0)
        self_emp_not_inc.append(0)
        self_emp_inc.append(1)
        federal_gov.append(0)
        local_gov.append(0)
        state_gov.append(0)
        without_pay.append(0)
        never_worked.append(0)
    elif work_class_values[i] == ' Federal-gov':
        private.append(0)
        self_emp_not_inc.append(0)
        self_emp_inc.append(0)
        federal_gov.append(1)
        local_gov.append(0)
        state_gov.append(0)
        without_pay.append(0)
        never_worked.append(0)
    elif work_class_values[i] == ' Local-gov':
        private.append(0)
        self_emp_not_inc.append(0)
        self_emp_inc.append(0)
        federal_gov.append(0)
        local_gov.append(1)
        state_gov.append(0)
        without_pay.append(0)
        never_worked.append(0)
    elif work_class_values[i] == ' State-gov':
        private.append(0)
        self_emp_not_inc.append(0)
        self_emp_inc.append(0)
        federal_gov.append(0)
        local_gov.append(0)
        state_gov.append(1)
        without_pay.append(0)
        never_worked.append(0)
    elif work_class_values[i] == ' Without-pay':
        private.append(0)
        self_emp_not_inc.append(0)
        self_emp_inc.append(0)
        federal_gov.append(0)
        local_gov.append(0)
        state_gov.append(0)
        without_pay.append(1)
        never_worked.append(0)
    elif work_class_values[i] == ' Never-worked':
        private.append(0)
        self_emp_not_inc.append(0)
        self_emp_inc.append(0)
        federal_gov.append(0)
        local_gov.append(0)
        state_gov.append(0)
        without_pay.append(0)
        never_worked.append(1)
    else:
        private.append(1)
        self_emp_not_inc.append(0)
        self_emp_inc.append(0)
        federal_gov.append(0)
        local_gov.append(0)
        state_gov.append(0)
        without_pay.append(0)
        never_worked.append(0)
        
adult_df['private'] = private
adult_df['self_emp_not_inc'] = self_emp_not_inc
adult_df['self_emp_inc'] = self_emp_inc
adult_df['federal_gov'] = federal_gov
adult_df['local_gov'] = local_gov
adult_df['state_gov'] = state_gov
adult_df['without_pay'] = without_pay
adult_df['never_worked'] = never_worked
adult_df = adult_df.drop('1', axis=1)

education_values = adult_df['3']

bachelors = []
some_college = []
eleven = []
hs_grad = []
prof_school = []
assoc_acdm = []
assoc_voc = []
nine = []
seven_eight = []
twelve = []
masters = []
one_four = []
ten = []
doctorate = []
five_six = []
preschool = []

for i in range(len(education_values)):
    if education_values[i] == ' Bachelors':
        bachelors.append(1)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' Some-college':
        bachelors.append(0)
        some_college.append(1)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' 11th':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(1)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' HS-grad':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(1)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' Prof-school':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(1)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' Assoc-acdm':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(1)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' Assoc-voc':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(1)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' 9th':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(1)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' 7th-8th':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(1)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' 12th':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(1)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' Masters':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(1)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' 1st-4th':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(1)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' 10th':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(1)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' Doctorate':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(1)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' 5th-6th':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(1)
        preschool.append(0)
    elif education_values[i] == ' Preschool':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(1)

adult_df['bachelors'] = bachelors
adult_df['some_college'] = some_college
adult_df['11th'] = eleven
adult_df['hs_grad'] = hs_grad
adult_df['prof_school'] = prof_school
adult_df['assoc_acdm'] = assoc_acdm
adult_df['assoc_voc'] = assoc_voc
adult_df['9th'] = nine
adult_df['7th_8th'] = seven_eight
adult_df['12th'] = twelve
adult_df['masters'] = masters
adult_df['1st_4th'] = one_four
adult_df['10th'] = ten
adult_df['doctorate'] = doctorate
adult_df['5th_6th'] = five_six
adult_df['preschool'] = preschool
adult_df = adult_df.drop('3',axis=1)

marital_status_values = adult_df['5']

married_civ_spouse = []
divorced = []
never_married = []
separated = []
widowed = []
married_spouse_absent = []
married_AF_spouse = []

for i in range(len(marital_status_values)):
    if marital_status_values[i] == ' Married-civ-spouse':
        married_civ_spouse.append(1)
        divorced.append(0)
        never_married.append(0)
        separated.append(0)
        widowed.append(0)
        married_spouse_absent.append(0)
        married_AF_spouse.append(0)
    elif marital_status_values[i] == ' Divorced':
        married_civ_spouse.append(0)
        divorced.append(1)
        never_married.append(0)
        separated.append(0)
        widowed.append(0)
        married_spouse_absent.append(0)
        married_AF_spouse.append(0)
    elif marital_status_values[i] == ' Never-married':
        married_civ_spouse.append(0)
        divorced.append(0)
        never_married.append(1)
        separated.append(0)
        widowed.append(0)
        married_spouse_absent.append(0)
        married_AF_spouse.append(0)
    elif marital_status_values[i] == ' Separated':
        married_civ_spouse.append(0)
        divorced.append(0)
        never_married.append(0)
        separated.append(1)
        widowed.append(0)
        married_spouse_absent.append(0)
        married_AF_spouse.append(0)
    elif marital_status_values[i] == ' Widowed':
        married_civ_spouse.append(0)
        divorced.append(0)
        never_married.append(0)
        separated.append(0)
        widowed.append(1)
        married_spouse_absent.append(0)
        married_AF_spouse.append(0)
    elif marital_status_values[i] == ' Married-spouse-absent':
        married_civ_spouse.append(0)
        divorced.append(0)
        never_married.append(0)
        separated.append(0)
        widowed.append(0)
        married_spouse_absent.append(1)
        married_AF_spouse.append(0)
    elif marital_status_values[i] == ' Married-AF-spouse':
        married_civ_spouse.append(0)
        divorced.append(0)
        never_married.append(0)
        separated.append(0)
        widowed.append(0)
        married_spouse_absent.append(0)
        married_AF_spouse.append(1)

adult_df['married_civ_spouse'] = married_civ_spouse
adult_df['divorced'] = divorced
adult_df['never_married'] = never_married
adult_df['separated'] = separated
adult_df['widowed'] = widowed
adult_df['married_spouse_absent'] = married_spouse_absent
adult_df['married_AF_spouse'] = married_AF_spouse
adult_df = adult_df.drop('5',axis=1)

occupation_values = adult_df['6']

tech_support = []
craft_repair = []
other_service = []
sales = []
exec_managerial = []
prof_specialty = []
handlers_cleaners = []
machine_op_inspct = []
adm_clerical = []
farming_fishing = []
transport_moving = []
priv_house_serv = []
protective_serv = []
armed_forces = []

for i in range(len(occupation_values)):
    if occupation_values[i] == ' Tech-support':
        tech_support.append(1)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Craft-repair':
        tech_support.append(0)
        craft_repair.append(1)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Other-service':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(1)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Sales':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(1)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Exec-managerial':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(1)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Prof-specialty':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(1)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Handlers-cleaners':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(1)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Machine-op-inspct':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(1)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Adm-clerical':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(1)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Farming-fishing':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(1)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Transport-moving':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(1)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Priv-house-serv':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(1)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Protective-serv':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(1)
        armed_forces.append(0)
    elif occupation_values[i] == ' Armed-Forces':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(1)
    elif occupation_values[i] == ' ?':
        tech_support.append(1)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
        
adult_df['tech_support'] = tech_support
adult_df['craft_repair'] = craft_repair
adult_df['other_service'] = other_service
adult_df['sales'] = sales
adult_df['exec_managerial'] = exec_managerial
adult_df['prof_specialty'] = prof_specialty
adult_df['handlers_cleaners'] = handlers_cleaners
adult_df['machine_op_inspct'] = machine_op_inspct
adult_df['adm_clerical'] = adm_clerical
adult_df['farming_fishing'] = farming_fishing
adult_df['transport_moving'] = transport_moving
adult_df['priv_house_serv'] = priv_house_serv
adult_df['protective_serv'] = protective_serv
adult_df['armed_forces'] = armed_forces
adult_df = adult_df.drop('6', axis=1)

relationship_values = adult_df['7']

wife = []
own_child = []
husband = []
not_in_family = []
other_relative = []
unmarried = []

for i in range(len(relationship_values)):
    if relationship_values[i] == ' Wife':
        wife.append(1)
        own_child.append(0)
        husband.append(0)
        not_in_family.append(0)
        other_relative.append(0)
        unmarried.append(0)
    elif relationship_values[i] == ' Own-child':
        wife.append(0)
        own_child.append(1)
        husband.append(0)
        not_in_family.append(0)
        other_relative.append(0)
        unmarried.append(0)
    elif relationship_values[i] == ' Husband':
        wife.append(0)
        own_child.append(0)
        husband.append(1)
        not_in_family.append(0)
        other_relative.append(0)
        unmarried.append(0)
    elif relationship_values[i] == ' Not-in-family':
        wife.append(0)
        own_child.append(0)
        husband.append(0)
        not_in_family.append(1)
        other_relative.append(0)
        unmarried.append(0)
    elif relationship_values[i] == ' Other-relative':
        wife.append(0)
        own_child.append(0)
        husband.append(0)
        not_in_family.append(0)
        other_relative.append(1)
        unmarried.append(0)
    elif relationship_values[i] == ' Unmarried':
        wife.append(0)
        own_child.append(0)
        husband.append(0)
        not_in_family.append(0)
        other_relative.append(0)
        unmarried.append(1)
        
adult_df['wife'] = wife
adult_df['own_child'] = own_child
adult_df['husband'] = husband
adult_df['not_in_family'] = not_in_family
adult_df['other_relative'] = other_relative
adult_df['unmarried'] = unmarried
adult_df = adult_df.drop('7', axis=1)

race_values = adult_df['8']

white = []
asian_pac_islander = []
amer_indian_eskimo = []
black = []
other = []

for i in range(len(race_values)):
    if race_values[i] == ' White':
        white.append(1)
        asian_pac_islander.append(0)
        amer_indian_eskimo.append(0)
        black.append(0)
        other.append(0)
    elif race_values[i] == ' Asian-Pac-Islander':
        white.append(0)
        asian_pac_islander.append(1)
        amer_indian_eskimo.append(0)
        black.append(0)
        other.append(0)
    elif race_values[i] == ' Amer-Indian-Eskimo':
        white.append(0)
        asian_pac_islander.append(0)
        amer_indian_eskimo.append(1)
        black.append(0)
        other.append(0)
    elif race_values[i] == ' Black':
        white.append(0)
        asian_pac_islander.append(0)
        amer_indian_eskimo.append(0)
        black.append(1)
        other.append(0)
    elif race_values[i] == ' Other':
        white.append(0)
        asian_pac_islander.append(0)
        amer_indian_eskimo.append(0)
        black.append(0)
        other.append(1)

adult_df['white'] = white
adult_df['asian_pac_islander'] = asian_pac_islander
adult_df['amer_indian_eskimo'] = amer_indian_eskimo
adult_df['black'] = black
adult_df['other'] = other
adult_df = adult_df.drop('8', axis=1)

gender_values = adult_df['9']
male = []
female = []

for i in range(len(gender_values)):
    if gender_values[i] == ' Male':
        male.append(1)
        female.append(0)
    elif gender_values[i] == ' Female':
        male.append(0)
        female.append(1)
        
adult_df['male'] = male
adult_df['female'] = female
adult_df = adult_df.drop('9', axis=1)

country_values = adult_df['13']

new_country_values = []

for i in range(len(country_values)):
    if country_values[i] == ' United-States':
        new_country_values.append(1)
    else:
        new_country_values.append(0)
        
adult_df['country'] = new_country_values
adult_df = adult_df.drop('13', axis = 1)

label_values = adult_df['14']
new_label = []

l1 = 0
l2 = 0
for i in range(len(label_values)):
    if label_values[i] == ' >50K':
        new_label.append(1)
        l1 += 1
    elif label_values[i] == ' >50K.':
        new_label.append(1)
        l2 += 1
    else:
        new_label.append(0)

adult_df['label'] = new_label
adult_df = adult_df.drop('14', axis=1)

adult_df['0'] = Normalize(adult_df['0'])
adult_df['2'] = Normalize(adult_df['2'])
adult_df['4'] = Normalize(adult_df['4'])
adult_df['10'] = Normalize(adult_df['10'])
adult_df['11'] = Normalize(adult_df['11'])
adult_df['12'] = Normalize(adult_df['12'])


adult_df_shuffle = adult_df.sample(frac=1).reset_index(drop=True)
adult_df_shuffle.to_csv('Datasets/Original_Datasets/Synthetic_Feature_Adult_Transformed.csv')

# %% [markdown]
# # Adult Data Abrupt and Gradual

# %%
original_adult_df = pd.read_csv('Datasets/Original_Datasets/Synthetic_Feature_Adult_Transformed.csv',header=None)
original_adult_df.columns = original_adult_df.columns.astype(str)
original_adult_df_x = original_adult_df.drop('65', axis=1)
original_adult_df_y = original_adult_df['65']
info_gain = mutual_info_classif(original_adult_df_x, original_adult_df_y, random_state=42)
for i in range(len(original_adult_df_x.columns)):
    print("Feature: " + original_adult_df_x.columns[i] + " --- Importance: " + str(info_gain[i]))
num_feature_shift = len(info_gain) * 0.25
print("Num Feature Shift: " + str(num_feature_shift))
print(np.sort(info_gain))

# %%
adult_df = pd.read_csv('Datasets/Original_Datasets/Synthetic_Feature_Adult_Transformed.csv',header=None)
adult_df.columns = adult_df.columns.astype(str)

thirty_o = adult_df['30']
fifty_three_o = adult_df['53']
three_o = adult_df['3']
zero_o = adult_df['0']
two_o = adult_df['2']
thirty_two_o = adult_df['32']
five_o = adult_df['5']
fifty_two_o = adult_df['52']
one_o = adult_df['1']
four_o = adult_df['4']
sixty_three_o = adult_df['63']
sixty_two_o = adult_df['62']
fifty_four_o = adult_df['54']
forty_one_o = adult_df['41']
fourteen_o = adult_df['14']
fourty_two_o = adult_df['42']

label = adult_df['65']

thirty_n = []
fifty_three_n = []
three_n = []
zero_n = []
two_n = []
thirty_two_n = []
five_n = []
fifty_two_n = []
one_n = []
four_n = []
sixty_three_n = []
sixty_two_n = []
fifty_four_n = []
forty_one_n = []
fourteen_n = []
fourty_two_n = []

# %%
Change_Point = len(label) / 2
for i in range(len(label)):
    if i <= Change_Point:
        thirty_n.append(thirty_o[i])
        fifty_three_n.append(fifty_three_o[i])
        three_n.append(three_o[i])
        zero_n.append(zero_o[i])
        two_n.append(two_o[i])
        thirty_two_n.append(thirty_two_o[i])
        five_n.append(five_o[i])
        fifty_two_n.append(fifty_two_o[i])
        one_n.append(one_o[i])
        four_n.append(four_o[i])
        sixty_three_n.append(sixty_three_o[i])
        sixty_two_n.append(sixty_two_o[i])
        fifty_four_n.append(fifty_four_o[i])
        forty_one_n.append(forty_one_o[i])
        fourteen_n.append(fourteen_o[i])
        fourty_two_n.append(fourty_two_o[i])
    else:
        if label[i] == 1:
            thirty_n.append(fourty_two_o[i])
            fifty_three_n.append(thirty_o[i])
            three_n.append(fifty_three_o[i])
            zero_n.append(three_o[i])
            two_n.append(zero_o[i])
            thirty_two_n.append(two_o[i])
            five_n.append(thirty_two_o[i])
            fifty_two_n.append(five_o[i])
            one_n.append(fifty_two_o[i])
            four_n.append(one_o[i])
            sixty_three_n.append(four_o[i])
            sixty_two_n.append(sixty_three_o[i])
            fifty_four_n.append(sixty_two_o[i])
            forty_one_n.append(fifty_four_o[i])
            fourteen_n.append(forty_one_o[i])
            fourty_two_n.append(fourteen_o[i])
        else:
            thirty_n.append(thirty_o[i])
            fifty_three_n.append(fifty_three_o[i])
            three_n.append(three_o[i])
            zero_n.append(zero_o[i])
            two_n.append(two_o[i])
            thirty_two_n.append(thirty_two_o[i])
            five_n.append(five_o[i])
            fifty_two_n.append(fifty_two_o[i])
            one_n.append(one_o[i])
            four_n.append(four_o[i])
            sixty_three_n.append(sixty_three_o[i])
            sixty_two_n.append(sixty_two_o[i])
            fifty_four_n.append(fifty_four_o[i])
            forty_one_n.append(forty_one_o[i])
            fourteen_n.append(fourteen_o[i])
            fourty_two_n.append(fourty_two_o[i])

adult_df['30'] = thirty_n
adult_df['53'] = fifty_three_n
adult_df['3'] = three_n
adult_df['0'] = zero_n
adult_df['2'] = two_n
adult_df['32'] = thirty_two_n
adult_df['5'] = five_n
adult_df['52'] = fifty_two_n
adult_df['1'] = one_n
adult_df['4'] = four_n
adult_df['63'] = sixty_three_n
adult_df['62'] = sixty_two_n
adult_df['54'] = fifty_four_n
adult_df['41'] = forty_one_n
adult_df['14'] = fourteen_n
adult_df['42'] = fourty_two_n

adult_df.to_csv('Datasets/Synthetic_Feature_Adult_Abrupt.csv')

# %%
adult_df = pd.read_csv('Datasets/Original_Datasets/Synthetic_Feature_Adult_Transformed.csv',header=None)
adult_df.columns = adult_df.columns.astype(str)

thirty_o = adult_df['30']
fifty_three_o = adult_df['53']
three_o = adult_df['3']
zero_o = adult_df['0']
two_o = adult_df['2']
thirty_two_o = adult_df['32']
five_o = adult_df['5']
fifty_two_o = adult_df['52']
one_o = adult_df['1']
four_o = adult_df['4']
sixty_three_o = adult_df['63']
sixty_two_o = adult_df['62']
fifty_four_o = adult_df['54']
forty_one_o = adult_df['41']
fourteen_o = adult_df['14']
fourty_two_o = adult_df['42']

label = adult_df['65']

thirty_n = []
fifty_three_n = []
three_n = []
zero_n = []
two_n = []
thirty_two_n = []
five_n = []
fifty_two_n = []
one_n = []
four_n = []
sixty_three_n = []
sixty_two_n = []
fifty_four_n = []
forty_one_n = []
fourteen_n = []
fourty_two_n = []

Change_Point = len(label) / 2
Width = len(label) * 0.1
print("Width: " + str(Width))
Shift_Num = 0
Shift_Expect = 1
Original_Flag = False


for i in range(len(label)):
    if i <= Change_Point:
        thirty_n.append(thirty_o[i])
        fifty_three_n.append(fifty_three_o[i])
        three_n.append(three_o[i])
        zero_n.append(zero_o[i])
        two_n.append(two_o[i])
        thirty_two_n.append(thirty_two_o[i])
        five_n.append(five_o[i])
        fifty_two_n.append(fifty_two_o[i])
        one_n.append(one_o[i])
        four_n.append(four_o[i])
        sixty_three_n.append(sixty_three_o[i])
        sixty_two_n.append(sixty_two_o[i])
        fifty_four_n.append(fifty_four_o[i])
        forty_one_n.append(forty_one_o[i])
        fourteen_n.append(fourteen_o[i])
        fourty_two_n.append(fourty_two_o[i])
    else:
        if i <= Change_Point + Width:
            if Original_Flag:
                print("Original")
                thirty_n.append(thirty_o[i])
                fifty_three_n.append(fifty_three_o[i])
                three_n.append(three_o[i])
                zero_n.append(zero_o[i])
                two_n.append(two_o[i])
                thirty_two_n.append(thirty_two_o[i])
                five_n.append(five_o[i])
                fifty_two_n.append(fifty_two_o[i])
                one_n.append(one_o[i])
                four_n.append(four_o[i])
                sixty_three_n.append(sixty_three_o[i])
                sixty_two_n.append(sixty_two_o[i])
                fifty_four_n.append(fifty_four_o[i])
                forty_one_n.append(forty_one_o[i])
                fourteen_n.append(fourteen_o[i])
                fourty_two_n.append(fourty_two_o[i])
                Original_Flag = False
            else:
                if Shift_Num < Shift_Expect:
                    print("Gradual Shift")
                    if label[i] == 1:
                        thirty_n.append(fourty_two_o[i])
                        fifty_three_n.append(thirty_o[i])
                        three_n.append(fifty_three_o[i])
                        zero_n.append(three_o[i])
                        two_n.append(zero_o[i])
                        thirty_two_n.append(two_o[i])
                        five_n.append(thirty_two_o[i])
                        fifty_two_n.append(five_o[i])
                        one_n.append(fifty_two_o[i])
                        four_n.append(one_o[i])
                        sixty_three_n.append(four_o[i])
                        sixty_two_n.append(sixty_three_o[i])
                        fifty_four_n.append(sixty_two_o[i])
                        forty_one_n.append(fifty_four_o[i])
                        fourteen_n.append(forty_one_o[i])
                        fourty_two_n.append(fourteen_o[i])
                    else:
                        thirty_n.append(thirty_o[i])
                        fifty_three_n.append(fifty_three_o[i])
                        three_n.append(three_o[i])
                        zero_n.append(zero_o[i])
                        two_n.append(two_o[i])
                        thirty_two_n.append(thirty_two_o[i])
                        five_n.append(five_o[i])
                        fifty_two_n.append(fifty_two_o[i])
                        one_n.append(one_o[i])
                        four_n.append(four_o[i])
                        sixty_three_n.append(sixty_three_o[i])
                        sixty_two_n.append(sixty_two_o[i])
                        fifty_four_n.append(fifty_four_o[i])
                        forty_one_n.append(forty_one_o[i])
                        fourteen_n.append(fourteen_o[i])
                        fourty_two_n.append(fourty_two_o[i])
                    Shift_Num = Shift_Num + 1
                if Shift_Num >= Shift_Expect:
                    Shift_Num = 0
                    Shift_Expect = Shift_Expect + 1
                    Original_Flag = True
        else:
            print("Shift")
            if label[i] == 1:
                thirty_n.append(fourty_two_o[i])
                fifty_three_n.append(thirty_o[i])
                three_n.append(fifty_three_o[i])
                zero_n.append(three_o[i])
                two_n.append(zero_o[i])
                thirty_two_n.append(two_o[i])
                five_n.append(thirty_two_o[i])
                fifty_two_n.append(five_o[i])
                one_n.append(fifty_two_o[i])
                four_n.append(one_o[i])
                sixty_three_n.append(four_o[i])
                sixty_two_n.append(sixty_three_o[i])
                fifty_four_n.append(sixty_two_o[i])
                forty_one_n.append(fifty_four_o[i])
                fourteen_n.append(forty_one_o[i])
                fourty_two_n.append(fourteen_o[i])
            else:
                thirty_n.append(thirty_o[i])
                fifty_three_n.append(fifty_three_o[i])
                three_n.append(three_o[i])
                zero_n.append(zero_o[i])
                two_n.append(two_o[i])
                thirty_two_n.append(thirty_two_o[i])
                five_n.append(five_o[i])
                fifty_two_n.append(fifty_two_o[i])
                one_n.append(one_o[i])
                four_n.append(four_o[i])
                sixty_three_n.append(sixty_three_o[i])
                sixty_two_n.append(sixty_two_o[i])
                fifty_four_n.append(fifty_four_o[i])
                forty_one_n.append(forty_one_o[i])
                fourteen_n.append(fourteen_o[i])
                fourty_two_n.append(fourty_two_o[i])
    
adult_df['30'] = thirty_n
adult_df['53'] = fifty_three_n
adult_df['3'] = three_n
adult_df['0'] = zero_n
adult_df['2'] = two_n
adult_df['32'] = thirty_two_n
adult_df['5'] = five_n
adult_df['52'] = fifty_two_n
adult_df['1'] = one_n
adult_df['4'] = four_n
adult_df['63'] = sixty_three_n
adult_df['62'] = sixty_two_n
adult_df['54'] = fifty_four_n
adult_df['41'] = forty_one_n
adult_df['14'] = fourteen_n
adult_df['42'] = fourty_two_n

adult_df.to_csv('Datasets/Synthetic_Feature_Adult_Gradual.csv')

# %% [markdown]
# # Bank Data Preprocess

# %%
bank_df = pd.read_csv('Datasets/Original_Datasets/original_bank.csv', header=None)
bank_df.columns = bank_df.columns.astype(str)

values_1 = bank_df['1']
management = []
technician = []
entrepreneur = []
blue_collar = []
unknown_1 = []
retired = []
admin = []
services = []
self_employed = []
unemployed = []
housemaid = []
student = []

for i in range(len(values_1)):
    if values_1[i] == '"management"':
        management.append(1)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"technician"':
        management.append(0)
        technician.append(1)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"entrepreneur"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(1)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"blue-collar"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(1)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"unknown"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(1)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"retired"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(1)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"admin."':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(1)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"services"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(1)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"self-employed"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(1)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"unemployed"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(1)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"unemployed"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(1)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"housemaid"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(1)
        student.append(0)
    elif values_1[i] == '"student"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(1)

bank_df['management'] = management
bank_df['technician'] = technician
bank_df['entrepreneur'] = entrepreneur
bank_df['blue_collar'] = blue_collar
bank_df['unknown_1'] = unknown_1
bank_df['retired'] = retired
bank_df['admin'] = admin
bank_df['services'] = services
bank_df['self_employed'] = self_employed
bank_df['unemployed'] = unemployed
bank_df['housemaid'] = housemaid
bank_df['student'] = student
bank_df = bank_df.drop('1',axis=1)

values_2 = bank_df['2']

married = []
single = []
divorced = []

for i in range(len(values_2)):
    if values_2[i] == '"married"':
        married.append(1)
        single.append(0)
        divorced.append(0)
    elif values_2[i] == '"single"':
        married.append(0)
        single.append(1)
        divorced.append(0)
    elif values_2[i] == '"divorced"':
        married.append(0)
        single.append(0)
        divorced.append(1)

bank_df['married'] = married
bank_df['single'] = single
bank_df['divorced'] = divorced
bank_df = bank_df.drop('2', axis=1)

values_3 = bank_df['3']

primary = []
secondary = []
tertiary = []
unknown_3 = []

for i in range(len(values_3)):
    if values_3[i] == '"primary"':
        primary.append(1)
        secondary.append(0)
        tertiary.append(0)
        unknown_3.append(0)
    elif values_3[i] == '"secondary"':
        primary.append(0)
        secondary.append(1)
        tertiary.append(0)
        unknown_3.append(0)
    elif values_3[i] == '"tertiary"':
        primary.append(0)
        secondary.append(0)
        tertiary.append(1)
        unknown_3.append(0)
    elif values_3[i] == '"unknown"':
        primary.append(0)
        secondary.append(0)
        tertiary.append(0)
        unknown_3.append(1)
        
bank_df['primary'] = primary  
bank_df['secondary'] = secondary
bank_df['tertiary'] = tertiary
bank_df['unknown_3'] = unknown_3
bank_df = bank_df.drop('3',axis=1)

values_4 = bank_df['4']

new_values_4 = []
for value in values_4:
    if value == '"no"':
        new_values_4.append(0)
    else:
        new_values_4.append(1)
bank_df['4'] = new_values_4

values_6 = bank_df['6']

new_values_6 = []
for value in values_6:
    if value == '"no"':
        new_values_6.append(0)
    else:
        new_values_6.append(1)
bank_df['6'] = new_values_6

values_7 = bank_df['7']

new_values_7 = []
for value in values_7:
    if value == '"no"':
        new_values_7.append(0)
    else:
        new_values_7.append(1)
bank_df['7'] = new_values_7

values_8 = bank_df['8']

celluar = []
telephone = []
unknown_8 = []

for value in values_8:
    if value == '"cellular"':
        celluar.append(1)
        telephone.append(0)
        unknown_8.append(0)
    elif value == '"telephone"':
        celluar.append(0)
        telephone.append(1)
        unknown_8.append(0)
    elif value == '"unknown"':
        celluar.append(0)
        telephone.append(0)
        unknown_8.append(1)

bank_df['celluar'] = celluar
bank_df['telephone'] = telephone
bank_df['unknown_8'] = unknown_8
bank_df = bank_df.drop('8',axis=1)

values_10 = bank_df['10']

jan = []
feb = []
mar = []
apr = []
may = []
jun = []
jul = []
aug = []
sep = []
oct = []
nov = []
dec = []

for value in values_10:
    if value == '"jan"':
        jan.append(1)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"feb"':
        jan.append(0)
        feb.append(1)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"mar"':
        jan.append(0)
        feb.append(0)
        mar.append(1)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"apr"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(1)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"may"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(1)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"jun"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(1)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"jul"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(1)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"aug"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(1)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"sep"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(1)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"oct"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(1)
        nov.append(0)
        dec.append(0)
    elif value == '"nov"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(1)
        dec.append(0)
    elif value == '"dec"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(1)

bank_df['jan'] = jan
bank_df['feb'] = feb
bank_df['mar'] = mar
bank_df['apr'] = apr
bank_df['may'] = may
bank_df['jun'] = jun
bank_df['jul'] = jul
bank_df['aug'] = aug
bank_df['sep'] = sep
bank_df['oct'] = oct
bank_df['nov'] = nov
bank_df['dec'] = dec
bank_df = bank_df.drop('10',axis=1)

values_15 = bank_df['15']

success = []
failure = []
other = []
unknown_15 = []

for value in values_15:
    if value == '"success"':
        success.append(1)
        failure.append(0)
        other.append(0)
        unknown_15.append(0)
    elif value == '"failure"':
        success.append(0)
        failure.append(1)
        other.append(0)
        unknown_15.append(0)
    elif value == '"other"':
        success.append(0)
        failure.append(0)
        other.append(1)
        unknown_15.append(0)
    elif value == '"unknown"':
        success.append(0)
        failure.append(0)
        other.append(0)
        unknown_15.append(1)

bank_df['success'] = success
bank_df['failure'] = failure
bank_df['other'] = other
bank_df['unknown_15'] = unknown_15
bank_df = bank_df.drop('15',axis=1)

values_16 = bank_df['16']
label = []

for value in values_16:
    if value == '"no"':
        label.append(0)
    else:
        label.append(1)

bank_df['label'] = label
bank_df = bank_df.drop('16',axis=1)

bank_df['0'] = Normalize(bank_df['0'])
bank_df['5'] = Normalize(bank_df['5'])
bank_df['9'] = Normalize(bank_df['9'])
bank_df['11'] = Normalize(bank_df['11'])
bank_df['12'] = Normalize(bank_df['12'])
bank_df['13'] = Normalize(bank_df['13'])
bank_df['14'] = Normalize(bank_df['14'])

bank_df_shullfe = bank_df.sample(frac=1).reset_index(drop=True)
bank_df_shullfe.to_csv('Datasets/Original_Datasets/Synthetic_Feature_Bank_Transformed.csv')

# %% [markdown]
# # Bank Data Abrupt and Gradual

# %%
original_bank_df = pd.read_csv('Datasets/Original_Datasets/Synthetic_Feature_Bank_Transformed.csv', header=None)
original_bank_df.columns = original_bank_df.columns.astype(str)
original_bank_df_x = original_bank_df.drop('48', axis=1)
original_bank_df_y = original_bank_df['48']
info_gain = mutual_info_classif(original_bank_df_x, original_bank_df_y, random_state=42)
for i in range(len(original_bank_df_x.columns)):
    print("Feature: " + original_bank_df_x.columns[i] + " --- Importance: " + str(info_gain[i]))
num_feature_shift = len(info_gain) * 0.25
print("Num Feature Shift: " + str(num_feature_shift))
print(np.sort(info_gain))

# %%
bank_df = pd.read_csv('Datasets/Original_Datasets/Synthetic_Feature_Bank_Transformed.csv',header=None)
bank_df.columns = bank_df.columns.astype(str)

six_o = bank_df['6']
forty_four_o = bank_df['44']
eight_o = bank_df['8']
two_o = bank_df['2']
forty_seven_o = bank_df['47']
three_o = bank_df['3']
thirty_one_o = bank_df['31']
nine_o = bank_df['9']
zero_o = bank_df['0']
twenty_nine_o = bank_df['29']
thirty_four_o = bank_df['34']
thirty_six_o = bank_df['36']
label = bank_df['48']



six_n = []
forty_four_n = []
eight_n = []
two_n = []
forty_seven_n = []
three_n = []
thirty_one_n = []
nine_n = []
zero_n = []
twenty_nine_n = []
thirty_n = []
thirty_four_n = []
thirty_six_n = []

# %%
bank_df = pd.read_csv('Datasets/Original_Datasets/Synthetic_Feature_Bank_Transformed.csv',header=None)
bank_df.columns = bank_df.columns.astype(str)

Change_Point = len(label) / 2

for i in range(len(label)):
    if i <= Change_Point:
        six_n.append(six_o[i])
        forty_four_n.append(forty_four_o[i])
        eight_n.append(eight_o[i])
        two_n.append(two_o[i])
        forty_seven_n.append(forty_seven_o[i])
        three_n.append(three_o[i])
        thirty_one_n.append(thirty_one_o[i])
        nine_n.append(nine_o[i])
        zero_n.append(zero_o[i])
        twenty_nine_n.append(twenty_nine_o[i])
        thirty_four_n.append(thirty_four_o[i])
        thirty_six_n.append(thirty_six_o[i])
    else:
        if label[i] == 1:
            six_n.append(thirty_six_o[i])
            forty_four_n.append(six_o[i])
            eight_n.append(forty_four_o[i])
            two_n.append(eight_o[i])
            forty_seven_n.append(two_o[i])
            three_n.append(forty_seven_o[i])
            thirty_one_n.append(three_o[i])
            nine_n.append(thirty_one_o[i])
            zero_n.append(nine_o[i])
            twenty_nine_n.append(zero_o[i])
            thirty_four_n.append(twenty_nine_o[i])
            thirty_six_n.append(thirty_four_o[i])
        else:
            six_n.append(six_o[i])
            forty_four_n.append(forty_four_o[i])
            eight_n.append(eight_o[i])
            two_n.append(two_o[i])
            forty_seven_n.append(forty_seven_o[i])
            three_n.append(three_o[i])
            thirty_one_n.append(thirty_one_o[i])
            nine_n.append(nine_o[i])
            zero_n.append(zero_o[i])
            twenty_nine_n.append(twenty_nine_o[i])
            thirty_four_n.append(thirty_four_o[i])
            thirty_six_n.append(thirty_six_o[i])

bank_df['6'] = six_n
bank_df['44'] = forty_four_n
bank_df['8'] = eight_n
bank_df['2'] = two_n
bank_df['47'] = forty_seven_n
bank_df['3'] = three_n
bank_df['31'] = thirty_one_n
bank_df['9'] = nine_n
bank_df['0'] = zero_n
bank_df['29'] = twenty_nine_n
bank_df['34'] = thirty_four_n
bank_df['36'] = thirty_six_n

bank_df.to_csv('Datasets/Synthetic_Feature_Bank_Abrupt.csv')

# %%
bank_df = pd.read_csv('Datasets/Original_Datasets/Synthetic_Feature_Bank_Transformed.csv',header=None)
bank_df.columns = bank_df.columns.astype(str)

six_o = bank_df['6']
forty_four_o = bank_df['44']
eight_o = bank_df['8']
two_o = bank_df['2']
forty_seven_o = bank_df['47']
three_o = bank_df['3']
thirty_one_o = bank_df['31']
nine_o = bank_df['9']
zero_o = bank_df['0']
twenty_nine_o = bank_df['29']
thirty_four_o = bank_df['34']
thirty_six_o = bank_df['36']
label = bank_df['48']

six_n = []
forty_four_n = []
eight_n = []
two_n = []
forty_seven_n = []
three_n = []
thirty_one_n = []
nine_n = []
zero_n = []
twenty_nine_n = []
thirty_n = []
thirty_four_n = []
thirty_six_n = []

Change_Point = len(label) / 2
Width = len(label) * 0.1
print("Width: " + str(Width))
Shift_Num = 0
Shift_Expect = 1
Original_Flag = False

for i in range(len(label)):
    if i <= Change_Point:
        six_n.append(six_o[i])
        forty_four_n.append(forty_four_o[i])
        eight_n.append(eight_o[i])
        two_n.append(two_o[i])
        forty_seven_n.append(forty_seven_o[i])
        three_n.append(three_o[i])
        thirty_one_n.append(thirty_one_o[i])
        nine_n.append(nine_o[i])
        zero_n.append(zero_o[i])
        twenty_nine_n.append(twenty_nine_o[i])
        thirty_four_n.append(thirty_four_o[i])
        thirty_six_n.append(thirty_six_o[i])
    else:
        if i < Change_Point + Width:
            if Original_Flag:
                print("Original")
                six_n.append(six_o[i])
                forty_four_n.append(forty_four_o[i])
                eight_n.append(eight_o[i])
                two_n.append(two_o[i])
                forty_seven_n.append(forty_seven_o[i])
                three_n.append(three_o[i])
                thirty_one_n.append(thirty_one_o[i])
                nine_n.append(nine_o[i])
                zero_n.append(zero_o[i])
                twenty_nine_n.append(twenty_nine_o[i])
                thirty_four_n.append(thirty_four_o[i])
                thirty_six_n.append(thirty_six_o[i])
                Original_Flag = False
            else:
                if Shift_Num < Shift_Expect:
                    print("Gradual Shift")
                    if label[i] == 1:
                        six_n.append(thirty_six_o[i])
                        forty_four_n.append(six_o[i])
                        eight_n.append(forty_four_o[i])
                        two_n.append(eight_o[i])
                        forty_seven_n.append(two_o[i])
                        three_n.append(forty_seven_o[i])
                        thirty_one_n.append(three_o[i])
                        nine_n.append(thirty_one_o[i])
                        zero_n.append(nine_o[i])
                        twenty_nine_n.append(zero_o[i])
                        thirty_four_n.append(twenty_nine_o[i])
                        thirty_six_n.append(thirty_four_o[i])
                    else:
                        six_n.append(six_o[i])
                        forty_four_n.append(forty_four_o[i])
                        eight_n.append(eight_o[i])
                        two_n.append(two_o[i])
                        forty_seven_n.append(forty_seven_o[i])
                        three_n.append(three_o[i])
                        thirty_one_n.append(thirty_one_o[i])
                        nine_n.append(nine_o[i])
                        zero_n.append(zero_o[i])
                        twenty_nine_n.append(twenty_nine_o[i])
                        thirty_four_n.append(thirty_four_o[i])
                        thirty_six_n.append(thirty_six_o[i])
                    Shift_Num = Shift_Num + 1
                    if Shift_Num >= Shift_Expect:
                            Shift_Num = 0
                            Shift_Expect = Shift_Expect + 1
                            Original_Flag = True 
        else:
            print("Shift")
            if label[i] == 1:
                six_n.append(thirty_six_o[i])
                forty_four_n.append(six_o[i])
                eight_n.append(forty_four_o[i])
                two_n.append(eight_o[i])
                forty_seven_n.append(two_o[i])
                three_n.append(forty_seven_o[i])
                thirty_one_n.append(three_o[i])
                nine_n.append(thirty_one_o[i])
                zero_n.append(nine_o[i])
                twenty_nine_n.append(zero_o[i])
                thirty_four_n.append(twenty_nine_o[i])
                thirty_six_n.append(thirty_four_o[i])
            else:
                six_n.append(six_o[i])
                forty_four_n.append(forty_four_o[i])
                eight_n.append(eight_o[i])
                two_n.append(two_o[i])
                forty_seven_n.append(forty_seven_o[i])
                three_n.append(three_o[i])
                thirty_one_n.append(thirty_one_o[i])
                nine_n.append(nine_o[i])
                zero_n.append(zero_o[i])
                twenty_nine_n.append(twenty_nine_o[i])
                thirty_four_n.append(thirty_four_o[i])
                thirty_six_n.append(thirty_six_o[i])

bank_df['6'] = six_n
bank_df['44'] = forty_four_n
bank_df['8'] = eight_n
bank_df['2'] = two_n
bank_df['47'] = forty_seven_n
bank_df['3'] = three_n
bank_df['31'] = thirty_one_n
bank_df['9'] = nine_n
bank_df['0'] = zero_n
bank_df['29'] = twenty_nine_n
bank_df['34'] = thirty_four_n
bank_df['36'] = thirty_six_n

bank_df.to_csv('Datasets/Synthetic_Feature_Bank_Gradual.csv')

# %% [markdown]
# # Credit Data Preprocess

# %%
credit_df = pd.read_csv('Datasets/Original_Datasets/original_credit.csv')

sex_values = credit_df['SEX']
new_sex_values = []
for i in range(len(sex_values)):
    if sex_values[i] == 1:
        new_sex_values.append(1)
    if sex_values[i] == 2:
        new_sex_values.append(0)
credit_df['SEX'] = new_sex_values
credit_df['SEX'] = credit_df['SEX'].astype('int')

education_values = credit_df['EDUCATION']
graduate_school = []
university = []
high_school = []
others = []
for i in range(len(education_values)):
    if education_values[i] == 1:
        graduate_school.append(1)
        university.append(0)
        high_school.append(0)
        others.append(0)
    elif education_values[i] == 2:
        graduate_school.append(0)
        university.append(1)
        high_school.append(0)
        others.append(0)
    elif education_values[i] == 3:
        graduate_school.append(0)
        university.append(0)
        high_school.append(1)
        others.append(0)
    else:
        graduate_school.append(0)
        university.append(0)
        high_school.append(0)
        others.append(1)
credit_df = credit_df.drop('EDUCATION', axis=1)
credit_df['education_graduate_school'] = graduate_school
credit_df['education_university'] = university
credit_df['education_high_school'] = high_school
credit_df['education_others'] = others

marriage_values = credit_df['MARRIAGE']
new_marriage_values = []
for i in range(len(marriage_values)):
    if marriage_values[i] == 1:
        new_marriage_values.append(1)
    else:
        new_marriage_values.append(0)
credit_df['MARRIAGE'] = new_marriage_values

credit_df['LIMIT_BAL'] = Normalize(credit_df['LIMIT_BAL'])
credit_df['AGE'] = Normalize(credit_df['AGE'])
credit_df['PAY_0'] = Normalize(credit_df['PAY_0'])
credit_df['PAY_2'] = Normalize(credit_df['PAY_2'])
credit_df['PAY_3'] = Normalize(credit_df['PAY_3'])
credit_df['PAY_4'] = Normalize(credit_df['PAY_4'])
credit_df['PAY_5'] = Normalize(credit_df['PAY_5'])
credit_df['PAY_6'] = Normalize(credit_df['PAY_6'])
credit_df['BILL_AMT1'] = Normalize(credit_df['BILL_AMT1'])
credit_df['BILL_AMT2'] = Normalize(credit_df['BILL_AMT2'])
credit_df['BILL_AMT3'] = Normalize(credit_df['BILL_AMT3'])
credit_df['BILL_AMT4'] = Normalize(credit_df['BILL_AMT4'])
credit_df['BILL_AMT5'] = Normalize(credit_df['BILL_AMT5'])
credit_df['BILL_AMT6'] = Normalize(credit_df['BILL_AMT6'])
credit_df['PAY_AMT1'] = Normalize(credit_df['PAY_AMT1'])
credit_df['PAY_AMT2'] = Normalize(credit_df['PAY_AMT2'])
credit_df['PAY_AMT3'] = Normalize(credit_df['PAY_AMT3'])
credit_df['PAY_AMT4'] = Normalize(credit_df['PAY_AMT4'])
credit_df['PAY_AMT5'] = Normalize(credit_df['PAY_AMT5'])
credit_df['PAY_AMT6'] = Normalize(credit_df['PAY_AMT6'])

label = credit_df['default payment next month']
credit_df['label'] = label
credit_df = credit_df.drop('default payment next month', axis=1)

# %%
credit_df_shuffle = credit_df.sample(frac=1).reset_index(drop=True)
credit_df_shuffle.to_csv('Datasets/Original_Datasets/Synthetic_Feature_Credit_Transformed.csv')

# %% [markdown]
# # Credit Data Abrupt and Gradual

# %%
original_credit_df = pd.read_csv('Datasets/Original_Datasets/Synthetic_Feature_Credit_Transformed.csv',header=None)
original_credit_df.columns = original_credit_df.columns.astype(str)
original_credit_df_x = original_credit_df.drop('26', axis=1)
original_credit_df_y = original_credit_df['26']
info_gain = mutual_info_classif(original_credit_df_x, original_credit_df_y, random_state=42)
for i in range(len(original_credit_df_x.columns)):
    print("Feature: " + original_credit_df_x.columns[i] + " --- Importance: " + str(info_gain[i]))
num_feature_shift = len(info_gain) * 0.25
print("Num Feature Shift: " + str(num_feature_shift))
print(np.sort(info_gain))

# %%
credit_df = pd.read_csv('Datasets/Original_Datasets/Synthetic_Feature_Credit_Transformed.csv', header=None)
credit_df.columns = credit_df.columns.astype(str)

four_o = credit_df['4']
five_o = credit_df['5']
eight_o = credit_df['8']
six_o = credit_df['6']
seven_o = credit_df['7']
sixteen_o = credit_df['16']
nine_o = credit_df['9']
label = credit_df['26']

four_n = []
five_n = []
eight_n = []
six_n = []
seven_n = []
sixteen_n = []
nine_n = []

# %%
Change_Point = len(label) / 2
for i in range(len(label)):
    if i <= Change_Point:
        four_n.append(four_o[i])
        five_n.append(five_o[i])
        eight_n.append(eight_o[i])
        six_n.append(six_o[i])
        seven_n.append(seven_o[i])
        sixteen_n.append(sixteen_o[i])
        nine_n.append(nine_o[i])
    else:
        if label[i] == 1:
            four_n.append(nine_o[i])
            five_n.append(four_o[i])
            eight_n.append(five_o[i])
            six_n.append(eight_o[i])
            seven_n.append(six_o[i])
            sixteen_n.append(seven_o[i])
            nine_n.append(sixteen_o[i])
        else:
            four_n.append(four_o[i])
            five_n.append(five_o[i])
            eight_n.append(eight_o[i])
            six_n.append(six_o[i])
            seven_n.append(seven_o[i])
            sixteen_n.append(sixteen_o[i])
            nine_n.append(nine_o[i])
            
credit_df['4'] = four_n
credit_df['5'] = five_n
credit_df['8'] = eight_n
credit_df['6'] = six_n
credit_df['7'] = seven_n
credit_df['16'] = sixteen_n
credit_df['9'] = nine_n

credit_df.to_csv('Datasets/Synthetic_Feature_Credit_Abrupt.csv')

# %%
credit_df = pd.read_csv('Datasets/Original_Datasets/Synthetic_Feature_Credit_Transformed.csv', header=None)
credit_df.columns = credit_df.columns.astype(str)

four_o = credit_df['4']
five_o = credit_df['5']
eight_o = credit_df['8']
six_o = credit_df['6']
seven_o = credit_df['7']
sixteen_o = credit_df['16']
nine_o = credit_df['9']
label = credit_df['26']

four_n = []
five_n = []
eight_n = []
six_n = []
seven_n = []
sixteen_n = []
nine_n = []

Change_Point = len(label) / 2
Width = len(label) * 0.1
print("Width: " + str(Width))
Shift_Num = 0
Shift_Expect = 1
Original_Flag = False

for i in range(len(label)):
    if i <= Change_Point:
        four_n.append(four_o[i])
        five_n.append(five_o[i])
        eight_n.append(eight_o[i])
        six_n.append(six_o[i])
        seven_n.append(seven_o[i])
        sixteen_n.append(sixteen_o[i])
        nine_n.append(nine_o[i])
    else:
        if i <= Change_Point + Width:
            if Original_Flag:
                print("Original")
                four_n.append(four_o[i])
                five_n.append(five_o[i])
                eight_n.append(eight_o[i])
                six_n.append(six_o[i])
                seven_n.append(seven_o[i])
                sixteen_n.append(sixteen_o[i])
                nine_n.append(nine_o[i])
                Original_Flag = False
            else:
                if Shift_Num < Shift_Expect:
                    print("Gradual Shift")
                    if label[i] == 1:
                        four_n.append(nine_o[i])
                        five_n.append(four_o[i])
                        eight_n.append(five_o[i])
                        six_n.append(eight_o[i])
                        seven_n.append(six_o[i])
                        sixteen_n.append(seven_o[i])
                        nine_n.append(sixteen_o[i])
                    else:
                        four_n.append(four_o[i])
                        five_n.append(five_o[i])
                        eight_n.append(eight_o[i])
                        six_n.append(six_o[i])
                        seven_n.append(seven_o[i])
                        sixteen_n.append(sixteen_o[i])
                        nine_n.append(nine_o[i])
                    Shift_Num = Shift_Num + 1
                if Shift_Num >= Shift_Expect:
                    Shift_Num = 0
                    Shift_Expect = Shift_Expect + 1
                    Original_Flag = True  
        else:
            print("Shift")
            if label[i] == 1:
                four_n.append(nine_o[i])
                five_n.append(four_o[i])
                eight_n.append(five_o[i])
                six_n.append(eight_o[i])
                seven_n.append(six_o[i])
                sixteen_n.append(seven_o[i])
                nine_n.append(sixteen_o[i])
            else:
                four_n.append(four_o[i])
                five_n.append(five_o[i])
                eight_n.append(eight_o[i])
                six_n.append(six_o[i])
                seven_n.append(seven_o[i])
                sixteen_n.append(sixteen_o[i])
                nine_n.append(nine_o[i])
                
credit_df['4'] = four_n
credit_df['5'] = five_n
credit_df['8'] = eight_n
credit_df['6'] = six_n
credit_df['7'] = seven_n
credit_df['16'] = sixteen_n
credit_df['9'] = nine_n

credit_df.to_csv('Datasets/Synthetic_Feature_Credit_Gradual.csv')

# %% [markdown]
# # Gamma Data Preprocess

# %% [raw]
# with open('Datasets/Original_Datasets/original_gamma.data') as csv_file:
#     csv_reader = csv.reader(csv_file, delimiter=',')
#     dataframe_list = []
#     columns_name = ['fLength','fWidth','fSize','fConc','fConc1','fAsym','fM3Long','fM3Trans','fAlpha','fDist','class']
#     for row in csv_reader:
#         dataframe_list.append(row)
#     gamma_df = pd.DataFrame(dataframe_list, columns=columns_name)
#
# class_value = gamma_df['class']
# new_class_value = []
# for i in range(len(class_value)):
#     if class_value[i] == 'g':
#         new_class_value.append(1)
#     else:
#         new_class_value.append(0)
# gamma_df['class'] = new_class_value
#
# gamma_df['fLength'] = gamma_df['fLength'].astype(float)
# gamma_df['fWidth'] = gamma_df['fWidth'].astype(float)
# gamma_df['fSize'] = gamma_df['fSize'].astype(float)
# gamma_df['fConc'] = gamma_df['fConc'].astype(float)
# gamma_df['fConc1'] = gamma_df['fConc1'].astype(float)
# gamma_df['fAsym'] = gamma_df['fAsym'].astype(float)
# gamma_df['fM3Long'] = gamma_df['fM3Long'].astype(float)
# gamma_df['fM3Trans'] = gamma_df['fM3Trans'].astype(float)
# gamma_df['fAlpha'] = gamma_df['fAlpha'].astype(float)
# gamma_df['fDist'] = gamma_df['fDist'].astype(float)
#
# gamma_df['fLength'] = Normalize(gamma_df['fLength'])
# gamma_df['fWidth'] = Normalize(gamma_df['fWidth'])
# gamma_df['fSize'] = Normalize(gamma_df['fSize'])
# gamma_df['fAsym'] = Normalize(gamma_df['fAsym'])
# gamma_df['fM3Long'] = Normalize(gamma_df['fM3Long'])
# gamma_df['fM3Trans'] = Normalize(gamma_df['fM3Trans'])
# gamma_df['fAlpha'] = Normalize(gamma_df['fAlpha'])
# gamma_df['fDist'] = Normalize(gamma_df['fDist'])
#
# gamma_df_shuffle = gamma_df.sample(frac=1).reset_index(drop=True)
# gamma_df_shuffle.to_csv('Datasets/Original_Datasets/Synthetic_Feature_Gamma_Transformed.csv')

# %% [markdown]
# # Gamma Data Abrupt and Gradual

# %%
original_gamma_df = pd.read_csv('Datasets/Original_Datasets/Synthetic_Feature_Gamma_Transformed.csv', header=None)
original_gamma_df.columns = original_gamma_df.columns.astype(str)
original_gamma_df_x = original_gamma_df.drop('10', axis=1)
original_gamma_df_y = original_gamma_df['10']
info_gain = mutual_info_classif(original_gamma_df_x, original_gamma_df_y, random_state=42)
for i in range(len(original_gamma_df_x.columns)):
    print("Feature: " + original_gamma_df_x.columns[i] + " --- Importance: " + str(info_gain[i]))
num_feature_shift = len(info_gain) * 0.25
print("Num Feature Shift: " + str(num_feature_shift))
print(np.sort(info_gain))

# %%
gamma_df = pd.read_csv('Datasets/Original_Datasets/Synthetic_Feature_Gamma_Transformed.csv', header=None)
gamma_df.columns = gamma_df.columns.astype(str)
eight_o = gamma_df['8']
one_o = gamma_df['1']
zero_o = gamma_df['0']
label = gamma_df['10']

eight_n = []
one_n = []
zero_n = []

# %%
Change_Point = len(label) / 2
for i in range(len(label)):
    if i <= Change_Point:
        eight_n.append(eight_o[i])
        one_n.append(one_o[i])
        zero_n.append(zero_o[i])
    else:
        if label[i] == 1:
            eight_n.append(zero_o[i])
            one_n.append(eight_o[i])
            zero_n.append(one_o[i])
        else:
            eight_n.append(eight_o[i])
            one_n.append(one_o[i])
            zero_n.append(zero_o[i])
            
gamma_df['8'] = eight_n
gamma_df['1'] = one_n
gamma_df['0'] = zero_n
gamma_df.to_csv('Datasets/Synthetic_Feature_Gamma_Abrupt.csv')

# %%
gamma_df = pd.read_csv('Datasets/Original_Datasets/Synthetic_Feature_Gamma_Transformed.csv', header=None)
gamma_df.columns = gamma_df.columns.astype(str)
eight_o = gamma_df['8']
one_o = gamma_df['1']
zero_o = gamma_df['0']
label = gamma_df['10']

eight_n = []
one_n = []
zero_n = []

Change_Point = len(label) / 2
Width = len(label) * 0.1
print("Width: " + str(Width))
Shift_Num = 0
Shift_Expect = 1
Original_Flag = False


for i in range(len(label)):
    if i <= Change_Point:
        eight_n.append(eight_o[i])
        one_n.append(one_o[i])
        zero_n.append(zero_o[i])
    else:
        if i <= Change_Point + Width:
            if Original_Flag:
                print("Original")
                eight_n.append(eight_o[i])
                one_n.append(one_o[i])
                zero_n.append(zero_o[i])
                Original_Flag = False
            else:
                if Shift_Num < Shift_Expect:
                    print("Gradual Shift")
                    if label[i] == 1:
                        eight_n.append(zero_o[i])
                        one_n.append(eight_o[i])
                        zero_n.append(one_o[i]) 
                    else:
                        eight_n.append(eight_o[i])
                        one_n.append(one_o[i])
                        zero_n.append(zero_o[i])
                    Shift_Num = Shift_Num + 1
                if Shift_Num >= Shift_Expect:
                    Shift_Num = 0
                    Shift_Expect = Shift_Expect + 1
                    Original_Flag = True
        else:
            print("Shift")
            if label[i] == 1:
                eight_n.append(zero_o[i])
                one_n.append(eight_o[i])
                zero_n.append(one_o[i])
            else:
                eight_n.append(eight_o[i])
                one_n.append(one_o[i])
                zero_n.append(zero_o[i])
            
gamma_df['8'] = eight_n
gamma_df['1'] = one_n
gamma_df['0'] = zero_n
gamma_df.to_csv('Datasets/Synthetic_Feature_Gamma_Gradual.csv')

# %% [markdown]
# # SEA Data Process

# %%
SEA_Abrupt_1 = pd.read_csv('Datasets/Original_Datasets/original_SEA_Abrupt.csv', header=None)
SEA_Abrupt_1.columns = SEA_Abrupt_1.columns.astype(str)
SEA_Abrupt_1['0'] = Normalize(SEA_Abrupt_1['0'])
SEA_Abrupt_1['1'] = Normalize(SEA_Abrupt_1['1'])
SEA_Abrupt_1['2'] = Normalize(SEA_Abrupt_1['2'])
SEA_Abrupt_1.to_csv('Datasets/Synthetic_MOA_SEA_Abrupt_1.csv')

# %%
SEA_Abrupt_2 = pd.read_csv('Datasets/Original_Datasets/original_SEA_Abrupt_2.csv', header=None)
SEA_Abrupt_2.columns = SEA_Abrupt_2.columns.astype(str)
SEA_Abrupt_2['0'] = Normalize(SEA_Abrupt_2['0'])
SEA_Abrupt_2['1'] = Normalize(SEA_Abrupt_2['1'])
SEA_Abrupt_2['2'] = Normalize(SEA_Abrupt_2['2'])
SEA_Abrupt_2.to_csv('Datasets/Synthetic_MOA_SEA_Abrupt_2.csv')

# %%
SEA_Gradual_1 = pd.read_csv('Datasets/Original_Datasets/original_SEA_Gradual.csv', header=None)
SEA_Gradual_1.columns = SEA_Gradual_1.columns.astype(str)
SEA_Gradual_1['0'] = Normalize(SEA_Gradual_1['0'])
SEA_Gradual_1['1'] = Normalize(SEA_Gradual_1['1'])
SEA_Gradual_1['2'] = Normalize(SEA_Gradual_1['2'])
SEA_Gradual_1.to_csv('Datasets/Synthetic_MOA_SEA_Gradual_1.csv')

# %%
SEA_Gradual_2 = pd.read_csv('Datasets/Original_Datasets/original_SEA_Gradual_2.csv', header=None)
SEA_Gradual_2.columns = SEA_Gradual_2.columns.astype(str)
SEA_Gradual_2['0'] = Normalize(SEA_Gradual_2['0'])
SEA_Gradual_2['1'] = Normalize(SEA_Gradual_2['1'])
SEA_Gradual_2['2'] = Normalize(SEA_Gradual_2['2'])
SEA_Gradual_2.to_csv('Datasets/Synthetic_MOA_SEA_Gradual_2.csv')

# %% [markdown]
# # RBF Data Process

# %% [markdown]
# # Agrawal Data Process

# %%
Agrawal_Abrupt = pd.read_csv('Datasets/Original_Datasets/original_Agrawal_Abrupt.csv',header=None)
Agrawal_Abrupt.columns = Agrawal_Abrupt.columns.astype(str)
Agrawal_Abrupt['0'] = Normalize(Agrawal_Abrupt['0'])
Agrawal_Abrupt['1'] = Normalize(Agrawal_Abrupt['1'])
Agrawal_Abrupt['2'] = Normalize(Agrawal_Abrupt['2'])
Agrawal_Abrupt['3'] = Normalize(Agrawal_Abrupt['3'])
Agrawal_Abrupt['4'] = Normalize(Agrawal_Abrupt['4'])
Agrawal_Abrupt['5'] = Normalize(Agrawal_Abrupt['5'])
Agrawal_Abrupt['6'] = Normalize(Agrawal_Abrupt['6'])
Agrawal_Abrupt['7'] = Normalize(Agrawal_Abrupt['7'])
Agrawal_Abrupt['8'] = Normalize(Agrawal_Abrupt['8'])
Agrawal_Abrupt.to_csv('Datasets/Synthetic_MOA_Agrawal_Abrupt.csv')

# %%
Agrawal_Gradual = pd.read_csv('Datasets/Original_Datasets/original_Agrawal_Gradual.csv', header=None)
Agrawal_Gradual.columns = Agrawal_Gradual.columns.astype(str)
Agrawal_Gradual['0'] = Normalize(Agrawal_Gradual['0'])
Agrawal_Gradual['1'] = Normalize(Agrawal_Gradual['1'])
Agrawal_Gradual['2'] = Normalize(Agrawal_Gradual['2'])
Agrawal_Gradual['3'] = Normalize(Agrawal_Gradual['3'])
Agrawal_Gradual['4'] = Normalize(Agrawal_Gradual['4'])
Agrawal_Gradual['5'] = Normalize(Agrawal_Gradual['5'])
Agrawal_Gradual['6'] = Normalize(Agrawal_Gradual['6'])
Agrawal_Gradual['7'] = Normalize(Agrawal_Gradual['7'])
Agrawal_Gradual['8'] = Normalize(Agrawal_Gradual['8'])
Agrawal_Gradual.to_csv('Datasets/Synthetic_MOA_Agrawal_Gradual.csv')
