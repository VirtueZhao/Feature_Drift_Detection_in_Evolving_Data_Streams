# %%
import csv
import pandas as pd
import numpy as np
from sklearn.feature_selection import mutual_info_classif

# %% [markdown]
# # Adult

# %%
original_adult_df = pd.read_csv('Datasets/s_f_Adult_Transformed.csv',header=None)
original_adult_df.columns = original_adult_df.columns.astype(str)
original_adult_df_x = original_adult_df.drop('65', axis=1)
original_adult_df_y = original_adult_df['65']
info_gain = mutual_info_classif(original_adult_df_x, original_adult_df_y, random_state=42)
for i in range(len(original_adult_df_x.columns)):
    print("Feature: " + original_adult_df_x.columns[i] + " --- Importance: " + str(info_gain[i]))
num_feature_shift = len(info_gain) * 0.25
print("Num Feature Shift: " + str(num_feature_shift))
print(np.sort(info_gain))

# %%
adult_df = pd.read_csv('Datasets/s_f_Adult_Transformed.csv',header=None)
adult_df.columns = adult_df.columns.astype(str)

thirty_o = adult_df['30']
fifty_three_o = adult_df['53']
two_o = adult_df['2']
zero_o = adult_df['0']
thirty_two_o = adult_df['32']
three_o = adult_df['3']
five_o = adult_df['5']
twenty_three_o = adult_df['23']
sixty_three_o = adult_df['63']
sixty_two_o = adult_df['62']
fifty_four_o = adult_df['54']
forty_one_o = adult_df['41']
fifty_six_o = adult_df['56']
twenty_four_o = adult_df['24']
forty_eight_o = adult_df['48']
six_o = adult_df['6']
label = adult_df['65']

thirty_n = []
fifty_three_n = []
two_n = []
zero_n = []
thirty_two_n = []
three_n = []
five_n = []
twenty_three_n = []
sixty_three_n = []
sixty_two_n = []
fifty_four_n = []
forty_one_n = []
fifty_six_n = []
twenty_four_n = []
forty_eight_n = []
six_n = []

# %%
Change_Point = len(label) / 2
for i in range(len(label)):
    if i <= Change_Point:
        thirty_n.append(thirty_o[i])
        fifty_three_n.append(fifty_three_o[i])
        two_n.append(two_o[i])
        zero_n.append(zero_o[i])
        thirty_two_n.append(thirty_two_o[i])
        three_n.append(three_o[i])
        five_n.append(five_o[i])
        twenty_three_n.append(twenty_three_o[i])
        sixty_three_n.append(sixty_three_o[i])
        sixty_two_n.append(sixty_two_o[i])
        fifty_four_n.append(fifty_four_o[i])
        forty_one_n.append(forty_one_o[i])
        fifty_six_n.append(fifty_six_o[i])
        twenty_four_n.append(twenty_four_o[i])
        forty_eight_n.append(forty_eight_o[i])
        six_n.append(six_o[i])
    else:
        if label[i] == 1:
            thirty_n.append(six_o[i])
            fifty_three_n.append(thirty_o[i])
            two_n.append(fifty_three_o[i])
            zero_n.append(two_o[i])
            thirty_two_n.append(zero_o[i])
            three_n.append(thirty_two_o[i])
            five_n.append(three_o[i])
            twenty_three_n.append(five_o[i])
            sixty_three_n.append(twenty_three_o[i])
            sixty_two_n.append(sixty_three_o[i])
            fifty_four_n.append(sixty_two_o[i])
            forty_one_n.append(fifty_four_o[i])
            fifty_six_n.append(forty_one_o[i])
            twenty_four_n.append(fifty_six_o[i])
            forty_eight_n.append(twenty_four_o[i])
            six_n.append(forty_eight_o[i])
        else:
            thirty_n.append(thirty_o[i])
            fifty_three_n.append(fifty_three_o[i])
            two_n.append(two_o[i])
            zero_n.append(zero_o[i])
            thirty_two_n.append(thirty_two_o[i])
            three_n.append(three_o[i])
            five_n.append(five_o[i])
            twenty_three_n.append(twenty_three_o[i])
            sixty_three_n.append(sixty_three_o[i])
            sixty_two_n.append(sixty_two_o[i])
            fifty_four_n.append(fifty_four_o[i])
            forty_one_n.append(forty_one_o[i])
            fifty_six_n.append(fifty_six_o[i])
            twenty_four_n.append(twenty_four_o[i])
            forty_eight_n.append(forty_eight_o[i])
            six_n.append(six_o[i])
            
adult_df['30'] = thirty_n
adult_df['53'] = fifty_three_n
adult_df['2'] = two_n
adult_df['0'] = zero_n
adult_df['32'] = thirty_two_n
adult_df['3'] = three_n
adult_df['5'] = five_n
adult_df['23'] = twenty_three_n
adult_df['63'] = sixty_three_n
adult_df['62'] = sixty_two_n
adult_df['54'] = fifty_four_n
adult_df['41'] = forty_one_n
adult_df['56'] = fifty_six_n
adult_df['24'] = twenty_four_n
adult_df['48'] = forty_eight_n
adult_df['6'] = six_n

adult_df.to_csv('s_f_Adult_Abrupt.csv')

# %%
adult_df = pd.read_csv('Datasets/s_f_Adult_Transformed.csv',header=None)
adult_df.columns = adult_df.columns.astype(str)

thirty_o = adult_df['30']
fifty_three_o = adult_df['53']
two_o = adult_df['2']
zero_o = adult_df['0']
thirty_two_o = adult_df['32']
three_o = adult_df['3']
five_o = adult_df['5']
twenty_three_o = adult_df['23']
sixty_three_o = adult_df['63']
sixty_two_o = adult_df['62']
fifty_four_o = adult_df['54']
forty_one_o = adult_df['41']
fifty_six_o = adult_df['56']
twenty_four_o = adult_df['24']
forty_eight_o = adult_df['48']
six_o = adult_df['6']
label = adult_df['65']

thirty_n = []
fifty_three_n = []
two_n = []
zero_n = []
thirty_two_n = []
three_n = []
five_n = []
twenty_three_n = []
sixty_three_n = []
sixty_two_n = []
fifty_four_n = []
forty_one_n = []
fifty_six_n = []
twenty_four_n = []
forty_eight_n = []
six_n = []

Change_Point = len(label) / 2
Width = len(label) * 0.1
print("Width: " + str(Width))
Shift_Num = 0
Shift_Expect = 1
Original_Flag = False

for i in range(len(label)):
    if i <= Change_Point:
        thirty_n.append(thirty_o[i])
        fifty_three_n.append(fifty_three_o[i])
        two_n.append(two_o[i])
        zero_n.append(zero_o[i])
        thirty_two_n.append(thirty_two_o[i])
        three_n.append(three_o[i])
        five_n.append(five_o[i])
        twenty_three_n.append(twenty_three_o[i])
        sixty_three_n.append(sixty_three_o[i])
        sixty_two_n.append(sixty_two_o[i])
        fifty_four_n.append(fifty_four_o[i])
        forty_one_n.append(forty_one_o[i])
        fifty_six_n.append(fifty_six_o[i])
        twenty_four_n.append(twenty_four_o[i])
        forty_eight_n.append(forty_eight_o[i])
        six_n.append(six_o[i])
    else:
        if i <= Change_Point + Width:
            if Original_Flag:
                print("Original")
                thirty_n.append(thirty_o[i])
                fifty_three_n.append(fifty_three_o[i])
                two_n.append(two_o[i])
                zero_n.append(zero_o[i])
                thirty_two_n.append(thirty_two_o[i])
                three_n.append(three_o[i])
                five_n.append(five_o[i])
                twenty_three_n.append(twenty_three_o[i])
                sixty_three_n.append(sixty_three_o[i])
                sixty_two_n.append(sixty_two_o[i])
                fifty_four_n.append(fifty_four_o[i])
                forty_one_n.append(forty_one_o[i])
                fifty_six_n.append(fifty_six_o[i])
                twenty_four_n.append(twenty_four_o[i])
                forty_eight_n.append(forty_eight_o[i])
                six_n.append(six_o[i])
                Original_Flag = False
            else:
                if Shift_Num < Shift_Expect:
                    print("Gradual Shift")
                    if label[i] == 1:
                        thirty_n.append(six_o[i])
                        fifty_three_n.append(thirty_o[i])
                        two_n.append(fifty_three_o[i])
                        zero_n.append(two_o[i])
                        thirty_two_n.append(zero_o[i])
                        three_n.append(thirty_two_o[i])
                        five_n.append(three_o[i])
                        twenty_three_n.append(five_o[i])
                        sixty_three_n.append(twenty_three_o[i])
                        sixty_two_n.append(sixty_three_o[i])
                        fifty_four_n.append(sixty_two_o[i])
                        forty_one_n.append(fifty_four_o[i])
                        fifty_six_n.append(forty_one_o[i])
                        twenty_four_n.append(fifty_six_o[i])
                        forty_eight_n.append(twenty_four_o[i])
                        six_n.append(forty_eight_o[i])
                    else:
                        thirty_n.append(thirty_o[i])
                        fifty_three_n.append(fifty_three_o[i])
                        two_n.append(two_o[i])
                        zero_n.append(zero_o[i])
                        thirty_two_n.append(thirty_two_o[i])
                        three_n.append(three_o[i])
                        five_n.append(five_o[i])
                        twenty_three_n.append(twenty_three_o[i])
                        sixty_three_n.append(sixty_three_o[i])
                        sixty_two_n.append(sixty_two_o[i])
                        fifty_four_n.append(fifty_four_o[i])
                        forty_one_n.append(forty_one_o[i])
                        fifty_six_n.append(fifty_six_o[i])
                        twenty_four_n.append(twenty_four_o[i])
                        forty_eight_n.append(forty_eight_o[i])
                        six_n.append(six_o[i])
                    Shift_Num = Shift_Num + 1
                if Shift_Num >= Shift_Expect:
                    Shift_Num = 0
                    Shift_Expect = Shift_Expect + 1
                    Original_Flag = True      
        else:
            print("Shift")
            if label[i] == 1:
                thirty_n.append(six_o[i])
                fifty_three_n.append(thirty_o[i])
                two_n.append(fifty_three_o[i])
                zero_n.append(two_o[i])
                thirty_two_n.append(zero_o[i])
                three_n.append(thirty_two_o[i])
                five_n.append(three_o[i])
                twenty_three_n.append(five_o[i])
                sixty_three_n.append(twenty_three_o[i])
                sixty_two_n.append(sixty_three_o[i])
                fifty_four_n.append(sixty_two_o[i])
                forty_one_n.append(fifty_four_o[i])
                fifty_six_n.append(forty_one_o[i])
                twenty_four_n.append(fifty_six_o[i])
                forty_eight_n.append(twenty_four_o[i])
                six_n.append(forty_eight_o[i])
            else:
                thirty_n.append(thirty_o[i])
                fifty_three_n.append(fifty_three_o[i])
                two_n.append(two_o[i])
                zero_n.append(zero_o[i])
                thirty_two_n.append(thirty_two_o[i])
                three_n.append(three_o[i])
                five_n.append(five_o[i])
                twenty_three_n.append(twenty_three_o[i])
                sixty_three_n.append(sixty_three_o[i])
                sixty_two_n.append(sixty_two_o[i])
                fifty_four_n.append(fifty_four_o[i])
                forty_one_n.append(forty_one_o[i])
                fifty_six_n.append(fifty_six_o[i])
                twenty_four_n.append(twenty_four_o[i])
                forty_eight_n.append(forty_eight_o[i])
                six_n.append(six_o[i])
            
adult_df['30'] = thirty_n
adult_df['53'] = fifty_three_n
adult_df['2'] = two_n
adult_df['0'] = zero_n
adult_df['32'] = thirty_two_n
adult_df['3'] = three_n
adult_df['5'] = five_n
adult_df['23'] = twenty_three_n
adult_df['63'] = sixty_three_n
adult_df['62'] = sixty_two_n
adult_df['54'] = fifty_four_n
adult_df['41'] = forty_one_n
adult_df['56'] = fifty_six_n
adult_df['24'] = twenty_four_n
adult_df['48'] = forty_eight_n
adult_df['6'] = six_n

adult_df.to_csv('s_f_Adult_Gradual.csv')

# %%
Change_Point_1 = len(label) / 4
Change_Point_2 = len(label) / 4 * 3

for i in range(len(label)):
    if i <= Change_Point_1 or i >= Change_Point_2:
        thirty_n.append(thirty_o[i])
        fifty_three_n.append(fifty_three_o[i])
        two_n.append(two_o[i])
        zero_n.append(zero_o[i])
        thirty_two_n.append(thirty_two_o[i])
        three_n.append(three_o[i])
        five_n.append(five_o[i])
        twenty_three_n.append(twenty_three_o[i])
        sixty_three_n.append(sixty_three_o[i])
        sixty_two_n.append(sixty_two_o[i])
        fifty_four_n.append(fifty_four_o[i])
        forty_one_n.append(forty_one_o[i])
        fifty_six_n.append(fifty_six_o[i])
        twenty_four_n.append(twenty_four_o[i])
        forty_eight_n.append(forty_eight_o[i])
        six_n.append(six_o[i])
    else:
        if label[i] == 1:
            print(1)
            thirty_n.append(six_o[i])
            fifty_three_n.append(thirty_o[i])
            two_n.append(fifty_three_o[i])
            zero_n.append(two_o[i])
            thirty_two_n.append(zero_o[i])
            three_n.append(thirty_two_o[i])
            five_n.append(three_o[i])
            twenty_three_n.append(five_o[i])
            sixty_three_n.append(twenty_three_o[i])
            sixty_two_n.append(sixty_three_o[i])
            fifty_four_n.append(sixty_two_o[i])
            forty_one_n.append(fifty_four_o[i])
            fifty_six_n.append(forty_one_o[i])
            twenty_four_n.append(fifty_six_o[i])
            forty_eight_n.append(twenty_four_o[i])
            six_n.append(forty_eight_o[i])
        else:
            thirty_n.append(thirty_o[i])
            fifty_three_n.append(fifty_three_o[i])
            two_n.append(two_o[i])
            zero_n.append(zero_o[i])
            thirty_two_n.append(thirty_two_o[i])
            three_n.append(three_o[i])
            five_n.append(five_o[i])
            twenty_three_n.append(twenty_three_o[i])
            sixty_three_n.append(sixty_three_o[i])
            sixty_two_n.append(sixty_two_o[i])
            fifty_four_n.append(fifty_four_o[i])
            forty_one_n.append(forty_one_o[i])
            fifty_six_n.append(fifty_six_o[i])
            twenty_four_n.append(twenty_four_o[i])
            forty_eight_n.append(forty_eight_o[i])
            six_n.append(six_o[i])
            
adult_df['30'] = thirty_n
adult_df['53'] = fifty_three_n
adult_df['2'] = two_n
adult_df['0'] = zero_n
adult_df['32'] = thirty_two_n
adult_df['3'] = three_n
adult_df['5'] = five_n
adult_df['23'] = twenty_three_n
adult_df['63'] = sixty_three_n
adult_df['62'] = sixty_two_n
adult_df['54'] = fifty_four_n
adult_df['41'] = forty_one_n
adult_df['56'] = fifty_six_n
adult_df['24'] = twenty_four_n
adult_df['48'] = forty_eight_n
adult_df['6'] = six_n

adult_df.to_csv('s_f_Adult_Recurrent.csv')

# %% [markdown]
# # Bank

# %%
original_bank_df = pd.read_csv('Datasets/s_f_Bank_Transformed.csv', header=None)
original_bank_df.columns = original_bank_df.columns.astype(str)
original_bank_df_x = original_bank_df.drop('48', axis=1)
original_bank_df_y = original_bank_df['48']
info_gain = mutual_info_classif(original_bank_df_x, original_bank_df_y, random_state=42)
for i in range(len(original_bank_df_x.columns)):
    print("Feature: " + original_bank_df_x.columns[i] + " --- Importance: " + str(info_gain[i]))
num_feature_shift = len(info_gain) * 0.25
print("Num Feature Shift: " + str(num_feature_shift))
print(np.sort(info_gain))

# %%
bank_df = pd.read_csv('Datasets/s_f_Bank_Transformed.csv',header=None)
bank_df.columns = bank_df.columns.astype(str)

six_o = bank_df['6']
forty_four_o = bank_df['44']
eight_o = bank_df['8']
forty_seven_o = bank_df['47']
twenty_nine_o = bank_df['29']
thirty_one_o = bank_df['31']
nine_o = bank_df['9']
zero_o = bank_df['0']
three_o = bank_df['3']
thirty_six_o = bank_df['36']
five_o = bank_df['5']
forty_o = bank_df['40']
label = bank_df['48']

six_n = []
forty_four_n = []
eight_n = []
forty_seven_n = []
twenty_nine_n = []
thirty_one_n = []
nine_n = []
zero_n = []
three_n = []
thirty_six_n = []
five_n = []
forty_n = []

# %%
Change_Point = len(label) / 2

for i in range(len(label)):
    if i <= Change_Point:
        six_n.append(six_o[i])
        forty_four_n.append(forty_four_o[i])
        eight_n.append(eight_o[i])
        forty_seven_n.append(forty_seven_o[i])
        twenty_nine_n.append(twenty_nine_o[i])
        thirty_one_n.append(thirty_one_o[i])
        nine_n.append(nine_o[i])
        zero_n.append(zero_o[i])
        three_n.append(three_o[i])
        thirty_six_n.append(thirty_six_o[i])
        five_n.append(five_o[i])
        forty_n.append(forty_o[i])
    else:
        if label[i] == 1:
            six_n.append(forty_o[i])
            forty_four_n.append(six_o[i])
            eight_n.append(forty_four_o[i])
            forty_seven_n.append(eight_o[i])
            twenty_nine_n.append(forty_four_o[i])
            thirty_one_n.append(twenty_nine_o[i])
            nine_n.append(thirty_one_o[i])
            zero_n.append(nine_o[i])
            three_n.append(zero_o[i])
            thirty_six_n.append(three_o[i])
            five_n.append(thirty_six_o[i])
            forty_n.append(five_o[i])
        else:
            six_n.append(six_o[i])
            forty_four_n.append(forty_four_o[i])
            eight_n.append(eight_o[i])
            forty_seven_n.append(forty_seven_o[i])
            twenty_nine_n.append(twenty_nine_o[i])
            thirty_one_n.append(thirty_one_o[i])
            nine_n.append(nine_o[i])
            zero_n.append(zero_o[i])
            three_n.append(three_o[i])
            thirty_six_n.append(thirty_six_o[i])
            five_n.append(five_o[i])
            forty_n.append(forty_o[i])

bank_df['6'] = six_n
bank_df['44'] = forty_four_n
bank_df['8'] = eight_n
bank_df['47'] = forty_seven_n
bank_df['29'] = twenty_nine_n
bank_df['31'] = thirty_one_n
bank_df['9'] = nine_n
bank_df['0'] = zero_n
bank_df['3'] = three_n
bank_df['36'] = thirty_six_n
bank_df['5'] = five_n
bank_df['40'] = forty_n

bank_df.to_csv('s_f_Bank_Abrupt.csv')

# %%
bank_df = pd.read_csv('Datasets/s_f_Bank_Transformed.csv',header=None)
bank_df.columns = bank_df.columns.astype(str)

six_o = bank_df['6']
forty_four_o = bank_df['44']
eight_o = bank_df['8']
forty_seven_o = bank_df['47']
twenty_nine_o = bank_df['29']
thirty_one_o = bank_df['31']
nine_o = bank_df['9']
zero_o = bank_df['0']
three_o = bank_df['3']
thirty_six_o = bank_df['36']
five_o = bank_df['5']
forty_o = bank_df['40']
label = bank_df['48']

six_n = []
forty_four_n = []
eight_n = []
forty_seven_n = []
twenty_nine_n = []
thirty_one_n = []
nine_n = []
zero_n = []
three_n = []
thirty_six_n = []
five_n = []
forty_n = []

Change_Point = len(label) / 2
Width = len(label) * 0.1
print("Width: " + str(Width))
Shift_Num = 0
Shift_Expect = 1
Original_Flag = False

for i in range(len(label)):
    if i <= Change_Point:
        six_n.append(six_o[i])
        forty_four_n.append(forty_four_o[i])
        eight_n.append(eight_o[i])
        forty_seven_n.append(forty_seven_o[i])
        twenty_nine_n.append(twenty_nine_o[i])
        thirty_one_n.append(thirty_one_o[i])
        nine_n.append(nine_o[i])
        zero_n.append(zero_o[i])
        three_n.append(three_o[i])
        thirty_six_n.append(thirty_six_o[i])
        five_n.append(five_o[i])
        forty_n.append(forty_o[i])
    else:
        if i <= Change_Point + Width:
            if Original_Flag:
                print("Original")
                six_n.append(six_o[i])
                forty_four_n.append(forty_four_o[i])
                eight_n.append(eight_o[i])
                forty_seven_n.append(forty_seven_o[i])
                twenty_nine_n.append(twenty_nine_o[i])
                thirty_one_n.append(thirty_one_o[i])
                nine_n.append(nine_o[i])
                zero_n.append(zero_o[i])
                three_n.append(three_o[i])
                thirty_six_n.append(thirty_six_o[i])
                five_n.append(five_o[i])
                forty_n.append(forty_o[i])
                Original_Flag = False
            else:
                if Shift_Num < Shift_Expect:
                    print("Gradual Shift")
                    if label[i] == 1:
                        six_n.append(forty_o[i])
                        forty_four_n.append(six_o[i])
                        eight_n.append(forty_four_o[i])
                        forty_seven_n.append(eight_o[i])
                        twenty_nine_n.append(forty_four_o[i])
                        thirty_one_n.append(twenty_nine_o[i])
                        nine_n.append(thirty_one_o[i])
                        zero_n.append(nine_o[i])
                        three_n.append(zero_o[i])
                        thirty_six_n.append(three_o[i])
                        five_n.append(thirty_six_o[i])
                        forty_n.append(five_o[i])
                    else:
                        six_n.append(six_o[i])
                        forty_four_n.append(forty_four_o[i])
                        eight_n.append(eight_o[i])
                        forty_seven_n.append(forty_seven_o[i])
                        twenty_nine_n.append(twenty_nine_o[i])
                        thirty_one_n.append(thirty_one_o[i])
                        nine_n.append(nine_o[i])
                        zero_n.append(zero_o[i])
                        three_n.append(three_o[i])
                        thirty_six_n.append(thirty_six_o[i])
                        five_n.append(five_o[i])
                        forty_n.append(forty_o[i])
                    Shift_Num = Shift_Num + 1
                    if Shift_Num >= Shift_Expect:
                        Shift_Num = 0
                        Shift_Expect = Shift_Expect + 1
                        Original_Flag = True 
        else:
            print("Shift")
            if label[i] == 1:
                six_n.append(forty_o[i])
                forty_four_n.append(six_o[i])
                eight_n.append(forty_four_o[i])
                forty_seven_n.append(eight_o[i])
                twenty_nine_n.append(forty_four_o[i])
                thirty_one_n.append(twenty_nine_o[i])
                nine_n.append(thirty_one_o[i])
                zero_n.append(nine_o[i])
                three_n.append(zero_o[i])
                thirty_six_n.append(three_o[i])
                five_n.append(thirty_six_o[i])
                forty_n.append(five_o[i])
            else:
                six_n.append(six_o[i])
                forty_four_n.append(forty_four_o[i])
                eight_n.append(eight_o[i])
                forty_seven_n.append(forty_seven_o[i])
                twenty_nine_n.append(twenty_nine_o[i])
                thirty_one_n.append(thirty_one_o[i])
                nine_n.append(nine_o[i])
                zero_n.append(zero_o[i])
                three_n.append(three_o[i])
                thirty_six_n.append(thirty_six_o[i])
                five_n.append(five_o[i])
                forty_n.append(forty_o[i])

bank_df['6'] = six_n
bank_df['44'] = forty_four_n
bank_df['8'] = eight_n
bank_df['47'] = forty_seven_n
bank_df['29'] = twenty_nine_n
bank_df['31'] = thirty_one_n
bank_df['9'] = nine_n
bank_df['0'] = zero_n
bank_df['3'] = three_n
bank_df['36'] = thirty_six_n
bank_df['5'] = five_n
bank_df['40'] = forty_n

bank_df.to_csv('s_f_Bank_Gradual.csv')

# %%
Change_Point_1 = len(label) / 4
Change_Point_2 = len(label) / 4 * 3

for i in range(len(label)):
    if i <= Change_Point_1 or i >= Change_Point_2:
        six_n.append(six_o[i])
        forty_four_n.append(forty_four_o[i])
        eight_n.append(eight_o[i])
        forty_seven_n.append(forty_seven_o[i])
        twenty_nine_n.append(twenty_nine_o[i])
        thirty_one_n.append(thirty_one_o[i])
        nine_n.append(nine_o[i])
        zero_n.append(zero_o[i])
        three_n.append(three_o[i])
        thirty_six_n.append(thirty_six_o[i])
        five_n.append(five_o[i])
        forty_n.append(forty_o[i])
    else:
        if label[i] == 1:
            six_n.append(forty_o[i])
            forty_four_n.append(six_o[i])
            eight_n.append(forty_four_o[i])
            forty_seven_n.append(eight_o[i])
            twenty_nine_n.append(forty_four_o[i])
            thirty_one_n.append(twenty_nine_o[i])
            nine_n.append(thirty_one_o[i])
            zero_n.append(nine_o[i])
            three_n.append(zero_o[i])
            thirty_six_n.append(three_o[i])
            five_n.append(thirty_six_o[i])
            forty_n.append(five_o[i])
        else:
            six_n.append(six_o[i])
            forty_four_n.append(forty_four_o[i])
            eight_n.append(eight_o[i])
            forty_seven_n.append(forty_seven_o[i])
            twenty_nine_n.append(twenty_nine_o[i])
            thirty_one_n.append(thirty_one_o[i])
            nine_n.append(nine_o[i])
            zero_n.append(zero_o[i])
            three_n.append(three_o[i])
            thirty_six_n.append(thirty_six_o[i])
            five_n.append(five_o[i])
            forty_n.append(forty_o[i])

bank_df['6'] = six_n
bank_df['44'] = forty_four_n
bank_df['8'] = eight_n
bank_df['47'] = forty_seven_n
bank_df['29'] = twenty_nine_n
bank_df['31'] = thirty_one_n
bank_df['9'] = nine_n
bank_df['0'] = zero_n
bank_df['3'] = three_n
bank_df['36'] = thirty_six_n
bank_df['5'] = five_n
bank_df['40'] = forty_n

bank_df.to_csv('s_f_Bank_Recurrent.csv')

# %% [markdown]
# # Credit

# %%
original_credit_df = pd.read_csv('Datasets/s_f_Credit_Transformed.csv',header=None)
original_credit_df.columns = original_credit_df.columns.astype(str)
original_credit_df_x = original_credit_df.drop('26', axis=1)
original_credit_df_y = original_credit_df['26']
info_gain = mutual_info_classif(original_credit_df_x, original_credit_df_y, random_state=42)
for i in range(len(original_credit_df_x.columns)):
    print("Feature: " + original_credit_df_x.columns[i] + " --- Importance: " + str(info_gain[i]))
num_feature_shift = len(info_gain) * 0.25
print("Num Feature Shift: " + str(num_feature_shift))
print(np.sort(info_gain))

# %%
credit_df = pd.read_csv('Datasets/s_f_Credit_Transformed.csv', header=None)
credit_df.columns = credit_df.columns.astype(str)

twenty_four_o = credit_df['24']
twenty_three_o = credit_df['23']
twenty_five_o = credit_df['25']
fifteen_o = credit_df['15']
one_o = credit_df['1']
twenty_two_o = credit_df['22']
six_o = credit_df['6']
label = credit_df['26']

twenty_four_n = []
twenty_three_n = []
twenty_five_n = []
fifteen_n = []
one_n = []
twenty_two_n = []
six_n = []

# %%
Change_Point = len(label) / 2
for i in range(len(label)):
    if i <= Change_Point:
        twenty_four_n.append(twenty_five_o[i])
        twenty_three_n.append(twenty_three_o[i])
        twenty_five_n.append(twenty_five_o[i])
        fifteen_n.append(fifteen_o[i])
        one_n.append(one_o[i])
        twenty_two_n.append(twenty_two_o[i])
        six_n.append(six_o[i])
    else:
        if label[i] == 1:
            twenty_four_n.append(six_o[i])
            twenty_three_n.append(twenty_four_o[i])
            twenty_five_n.append(twenty_three_o[i])
            fifteen_n.append(twenty_five_o[i])
            one_n.append(fifteen_o[i])
            twenty_two_n.append(one_o[i])
            six_n.append(twenty_two_o[i])
        else:
            twenty_four_n.append(twenty_five_o[i])
            twenty_three_n.append(twenty_three_o[i])
            twenty_five_n.append(twenty_five_o[i])
            fifteen_n.append(fifteen_o[i])
            one_n.append(one_o[i])
            twenty_two_n.append(twenty_two_o[i])
            six_n.append(six_o[i])
            
credit_df['24'] = twenty_four_n
credit_df['23'] = twenty_three_n
credit_df['25'] = twenty_five_n
credit_df['15'] = fifteen_n
credit_df['1'] = one_n
credit_df['22'] = twenty_two_n
credit_df['6'] = six_n
credit_df.to_csv('s_f_Credit_Abrupt.csv')

# %%
credit_df = pd.read_csv('Datasets/s_f_Credit_Transformed.csv', header=None)
credit_df.columns = credit_df.columns.astype(str)

twenty_four_o = credit_df['24']
twenty_three_o = credit_df['23']
twenty_five_o = credit_df['25']
fifteen_o = credit_df['15']
one_o = credit_df['1']
twenty_two_o = credit_df['22']
six_o = credit_df['6']
label = credit_df['26']

twenty_four_n = []
twenty_three_n = []
twenty_five_n = []
fifteen_n = []
one_n = []
twenty_two_n = []
six_n = []

Change_Point = len(label) / 2
Width = len(label) * 0.1
print("Width: " + str(Width))
Shift_Num = 0
Shift_Expect = 1
Original_Flag = False

for i in range(len(label)):
    if i <= Change_Point:
        twenty_four_n.append(twenty_five_o[i])
        twenty_three_n.append(twenty_three_o[i])
        twenty_five_n.append(twenty_five_o[i])
        fifteen_n.append(fifteen_o[i])
        one_n.append(one_o[i])
        twenty_two_n.append(twenty_two_o[i])
        six_n.append(six_o[i])
    else:
        if i <= Change_Point + Width:
            if Original_Flag:
                print("Original")
                twenty_four_n.append(twenty_five_o[i])
                twenty_three_n.append(twenty_three_o[i])
                twenty_five_n.append(twenty_five_o[i])
                fifteen_n.append(fifteen_o[i])
                one_n.append(one_o[i])
                twenty_two_n.append(twenty_two_o[i])
                six_n.append(six_o[i])
                Original_Flag = False
            else:
                if Shift_Num < Shift_Expect:
                    print("Gradual Shift")
                    if label[i] == 1:
                        twenty_four_n.append(six_o[i])
                        twenty_three_n.append(twenty_four_o[i])
                        twenty_five_n.append(twenty_three_o[i])
                        fifteen_n.append(twenty_five_o[i])
                        one_n.append(fifteen_o[i])
                        twenty_two_n.append(one_o[i])
                        six_n.append(twenty_two_o[i])
                    else:
                        twenty_four_n.append(twenty_five_o[i])
                        twenty_three_n.append(twenty_three_o[i])
                        twenty_five_n.append(twenty_five_o[i])
                        fifteen_n.append(fifteen_o[i])
                        one_n.append(one_o[i])
                        twenty_two_n.append(twenty_two_o[i])
                        six_n.append(six_o[i])
                    Shift_Num = Shift_Num + 1
                if Shift_Num >= Shift_Expect:
                    Shift_Num = 0
                    Shift_Expect = Shift_Expect + 1
                    Original_Flag = True  
        else:
            print("Shift")
            if label[i] == 1:
                twenty_four_n.append(six_o[i])
                twenty_three_n.append(twenty_four_o[i])
                twenty_five_n.append(twenty_three_o[i])
                fifteen_n.append(twenty_five_o[i])
                one_n.append(fifteen_o[i])
                twenty_two_n.append(one_o[i])
                six_n.append(twenty_two_o[i])
            else:
                twenty_four_n.append(twenty_five_o[i])
                twenty_three_n.append(twenty_three_o[i])
                twenty_five_n.append(twenty_five_o[i])
                fifteen_n.append(fifteen_o[i])
                one_n.append(one_o[i])
                twenty_two_n.append(twenty_two_o[i])
                six_n.append(six_o[i])
            
credit_df['24'] = twenty_four_n
credit_df['23'] = twenty_three_n
credit_df['25'] = twenty_five_n
credit_df['15'] = fifteen_n
credit_df['1'] = one_n
credit_df['22'] = twenty_two_n
credit_df['6'] = six_n
credit_df.to_csv('s_f_Credit_Gradual.csv')

# %%
Change_Point_1 = len(label) / 4
Change_Point_2 = len(label) / 4 * 3

for i in range(len(label)):
    if i <= Change_Point_1 or i >= Change_Point_2:
        twenty_four_n.append(twenty_five_o[i])
        twenty_three_n.append(twenty_three_o[i])
        twenty_five_n.append(twenty_five_o[i])
        fifteen_n.append(fifteen_o[i])
        one_n.append(one_o[i])
        twenty_two_n.append(twenty_two_o[i])
        six_n.append(six_o[i])
    else:
        if label[i] == 1:
            twenty_four_n.append(six_o[i])
            twenty_three_n.append(twenty_four_o[i])
            twenty_five_n.append(twenty_three_o[i])
            fifteen_n.append(twenty_five_o[i])
            one_n.append(fifteen_o[i])
            twenty_two_n.append(one_o[i])
            six_n.append(twenty_two_o[i])
        else:
            twenty_four_n.append(twenty_five_o[i])
            twenty_three_n.append(twenty_three_o[i])
            twenty_five_n.append(twenty_five_o[i])
            fifteen_n.append(fifteen_o[i])
            one_n.append(one_o[i])
            twenty_two_n.append(twenty_two_o[i])
            six_n.append(six_o[i])
            
credit_df['24'] = twenty_four_n
credit_df['23'] = twenty_three_n
credit_df['25'] = twenty_five_n
credit_df['15'] = fifteen_n
credit_df['1'] = one_n
credit_df['22'] = twenty_two_n
credit_df['6'] = six_n
credit_df.to_csv('s_f_Credit_Recurrent.csv')

# %% [markdown]
# # Gamma

# %%
original_gamma_df = pd.read_csv('Datasets/s_f_Gamma_Transformed.csv', header=None)
original_gamma_df.columns = original_gamma_df.columns.astype(str)
original_gamma_df_x = original_gamma_df.drop('10', axis=1)
original_gamma_df_y = original_gamma_df['10']
info_gain = mutual_info_classif(original_gamma_df_x, original_gamma_df_y, random_state=42)
for i in range(len(original_gamma_df_x.columns)):
    print("Feature: " + original_gamma_df_x.columns[i] + " --- Importance: " + str(info_gain[i]))
num_feature_shift = len(info_gain) * 0.25
print("Num Feature Shift: " + str(num_feature_shift))
print(np.sort(info_gain))

# %%
gamma_df = pd.read_csv('Datasets/s_f_Gamma_Transformed.csv', header=None)
gamma_df.columns = gamma_df.columns.astype(str)
eight_o = gamma_df['8']
one_o = gamma_df['1']
six_o = gamma_df['6']
label = gamma_df['10']

eight_n = []
one_n = []
six_n = []

# %%
Change_Point = len(label) / 2
for i in range(len(label)):
    if i <= Change_Point:
        eight_n.append(eight_o[i])
        one_n.append(one_o[i])
        six_n.append(six_o[i])
    else:
        if label[i] == 1:
            eight_n.append(six_o[i])
            one_n.append(eight_o[i])
            six_n.append(one_o[i])
        else:
            eight_n.append(eight_o[i])
            one_n.append(one_o[i])
            six_n.append(six_o[i]) 

gamma_df['8'] = eight_n
gamma_df['1'] = one_n
gamma_df['6'] = six_n
gamma_df.to_csv('s_f_Gamma_Abrupt.csv')

# %%
gamma_df = pd.read_csv('Datasets/s_f_Gamma_Transformed.csv', header=None)
gamma_df.columns = gamma_df.columns.astype(str)
eight_o = gamma_df['8']
one_o = gamma_df['1']
six_o = gamma_df['6']
label = gamma_df['10']

eight_n = []
one_n = []
six_n = []

Change_Point = len(label) / 2
Width = len(label) * 0.1
print("Width: " + str(Width))
Shift_Num = 0
Shift_Expect = 1
Original_Flag = False

for i in range(len(label)):
    if i <= Change_Point:
        eight_n.append(eight_o[i])
        one_n.append(one_o[i])
        six_n.append(six_o[i])
    else:
        if i <= Change_Point + Width:
            if Original_Flag:
                print("Original")
                eight_n.append(eight_o[i])
                one_n.append(one_o[i])
                six_n.append(six_o[i])
                Original_Flag = False
            else:
                if Shift_Num < Shift_Expect:
                    print("Gradual Shift")
                    if label[i] == 1:
                        eight_n.append(six_o[i])
                        one_n.append(eight_o[i])
                        six_n.append(one_o[i])
                    else:
                        eight_n.append(eight_o[i])
                        one_n.append(one_o[i])
                        six_n.append(six_o[i])
                    Shift_Num = Shift_Num + 1
                if Shift_Num >= Shift_Expect:
                    Shift_Num = 0
                    Shift_Expect = Shift_Expect + 1
                    Original_Flag = True 
        else:
            print("Shift")
            if label[i] == 1:
                eight_n.append(six_o[i])
                one_n.append(eight_o[i])
                six_n.append(one_o[i])
            else:
                eight_n.append(eight_o[i])
                one_n.append(one_o[i])
                six_n.append(six_o[i]) 

gamma_df['8'] = eight_n
gamma_df['1'] = one_n
gamma_df['6'] = six_n
gamma_df.to_csv('s_f_Gamma_Gradual.csv')
# Out:
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Original
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Gradual Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# ...
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift
# Shift

# %%
Change_Point_1 = len(label) / 4
Change_Point_2 = len(label) / 4 * 3

for i in range(len(label)):
    if i <= Change_Point_1 or i >= Change_Point_2:
        eight_n.append(eight_o[i])
        one_n.append(one_o[i])
        six_n.append(six_o[i])
    else:
        if label[i] == 1:
            eight_n.append(six_o[i])
            one_n.append(eight_o[i])
            six_n.append(one_o[i])
        else:
            eight_n.append(eight_o[i])
            one_n.append(one_o[i])
            six_n.append(six_o[i]) 

gamma_df['8'] = eight_n
gamma_df['1'] = one_n
gamma_df['6'] = six_n
gamma_df.to_csv('s_f_Gamma_Recurrent.csv')
