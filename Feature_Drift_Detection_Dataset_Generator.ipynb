# %%
import csv
import pandas as pd
import numpy as np
from sklearn.feature_selection import mutual_info_classif
from sklearn import preprocessing

# %%
def Normalize(data_array):
    max = data_array.max()
    min = data_array.min()
    new_values = []
    for i in range(len(data_array)):
        new_value = (data_array[i] - min) / (max - min)
        new_values.append(new_value)

    return new_values

# %% [markdown]
# # Bank

# %%
bank_df = pd.read_csv("Datasets_original/original_bank.csv",header=None)
bank_df.columns = bank_df.columns.astype(str)

# %%
values_1 = bank_df['1']
management = []
technician = []
entrepreneur = []
blue_collar = []
unknown_1 = []
retired = []
admin = []
services = []
self_employed = []
unemployed = []
housemaid = []
student = []

for i in range(len(values_1)):
    if values_1[i] == '"management"':
        management.append(1)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"technician"':
        management.append(0)
        technician.append(1)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"entrepreneur"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(1)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"blue-collar"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(1)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"unknown"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(1)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"retired"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(1)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"admin."':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(1)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"services"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(1)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"self-employed"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(1)
        unemployed.append(0)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"unemployed"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(1)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"unemployed"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(1)
        housemaid.append(0)
        student.append(0)
    elif values_1[i] == '"housemaid"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(1)
        student.append(0)
    elif values_1[i] == '"student"':
        management.append(0)
        technician.append(0)
        entrepreneur.append(0)
        blue_collar.append(0)
        unknown_1.append(0)
        retired.append(0)
        admin.append(0)
        services.append(0)
        self_employed.append(0)
        unemployed.append(0)
        housemaid.append(0)
        student.append(1)

bank_df['management'] = management
bank_df['technician'] = technician
bank_df['entrepreneur'] = entrepreneur
bank_df['blue_collar'] = blue_collar
bank_df['unknown_1'] = unknown_1
bank_df['retired'] = retired
bank_df['admin'] = admin
bank_df['services'] = services
bank_df['self_employed'] = self_employed
bank_df['unemployed'] = unemployed
bank_df['housemaid'] = housemaid
bank_df['student'] = student
bank_df = bank_df.drop('1',axis=1)

values_2 = bank_df['2']

married = []
single = []
divorced = []

for i in range(len(values_2)):
    if values_2[i] == '"married"':
        married.append(1)
        single.append(0)
        divorced.append(0)
    elif values_2[i] == '"single"':
        married.append(0)
        single.append(1)
        divorced.append(0)
    elif values_2[i] == '"divorced"':
        married.append(0)
        single.append(0)
        divorced.append(1)

bank_df['married'] = married
bank_df['single'] = single
bank_df['divorced'] = divorced
bank_df = bank_df.drop('2', axis=1)

values_3 = bank_df['3']

primary = []
secondary = []
tertiary = []
unknown_3 = []

for i in range(len(values_3)):
    if values_3[i] == '"primary"':
        primary.append(1)
        secondary.append(0)
        tertiary.append(0)
        unknown_3.append(0)
    elif values_3[i] == '"secondary"':
        primary.append(0)
        secondary.append(1)
        tertiary.append(0)
        unknown_3.append(0)
    elif values_3[i] == '"tertiary"':
        primary.append(0)
        secondary.append(0)
        tertiary.append(1)
        unknown_3.append(0)
    elif values_3[i] == '"unknown"':
        primary.append(0)
        secondary.append(0)
        tertiary.append(0)
        unknown_3.append(1)
        
bank_df['primary'] = primary  
bank_df['secondary'] = secondary
bank_df['tertiary'] = tertiary
bank_df['unknown_3'] = unknown_3
bank_df = bank_df.drop('3',axis=1)

values_4 = bank_df['4']

new_values_4 = []
for value in values_4:
    if value == '"no"':
        new_values_4.append(0)
    else:
        new_values_4.append(1)
bank_df['4'] = new_values_4

values_6 = bank_df['6']

new_values_6 = []
for value in values_6:
    if value == '"no"':
        new_values_6.append(0)
    else:
        new_values_6.append(1)
bank_df['6'] = new_values_6

values_7 = bank_df['7']

new_values_7 = []
for value in values_7:
    if value == '"no"':
        new_values_7.append(0)
    else:
        new_values_7.append(1)
bank_df['7'] = new_values_7

values_8 = bank_df['8']

celluar = []
telephone = []
unknown_8 = []

for value in values_8:
    if value == '"cellular"':
        celluar.append(1)
        telephone.append(0)
        unknown_8.append(0)
    elif value == '"telephone"':
        celluar.append(0)
        telephone.append(1)
        unknown_8.append(0)
    elif value == '"unknown"':
        celluar.append(0)
        telephone.append(0)
        unknown_8.append(1)

bank_df['celluar'] = celluar
bank_df['telephone'] = telephone
bank_df['unknown_8'] = unknown_8
bank_df = bank_df.drop('8',axis=1)

values_10 = bank_df['10']

jan = []
feb = []
mar = []
apr = []
may = []
jun = []
jul = []
aug = []
sep = []
oct = []
nov = []
dec = []

for value in values_10:
    if value == '"jan"':
        jan.append(1)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"feb"':
        jan.append(0)
        feb.append(1)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"mar"':
        jan.append(0)
        feb.append(0)
        mar.append(1)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"apr"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(1)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"may"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(1)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"jun"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(1)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"jul"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(1)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"aug"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(1)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"sep"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(1)
        oct.append(0)
        nov.append(0)
        dec.append(0)
    elif value == '"oct"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(1)
        nov.append(0)
        dec.append(0)
    elif value == '"nov"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(1)
        dec.append(0)
    elif value == '"dec"':
        jan.append(0)
        feb.append(0)
        mar.append(0)
        apr.append(0)
        may.append(0)
        jun.append(0)
        jul.append(0)
        aug.append(0)
        sep.append(0)
        oct.append(0)
        nov.append(0)
        dec.append(1)

bank_df['jan'] = jan
bank_df['feb'] = feb
bank_df['mar'] = mar
bank_df['apr'] = apr
bank_df['may'] = may
bank_df['jun'] = jun
bank_df['jul'] = jul
bank_df['aug'] = aug
bank_df['sep'] = sep
bank_df['oct'] = oct
bank_df['nov'] = nov
bank_df['dec'] = dec
bank_df = bank_df.drop('10',axis=1)

values_15 = bank_df['15']

success = []
failure = []
other = []
unknown_15 = []

for value in values_15:
    if value == '"success"':
        success.append(1)
        failure.append(0)
        other.append(0)
        unknown_15.append(0)
    elif value == '"failure"':
        success.append(0)
        failure.append(1)
        other.append(0)
        unknown_15.append(0)
    elif value == '"other"':
        success.append(0)
        failure.append(0)
        other.append(1)
        unknown_15.append(0)
    elif value == '"unknown"':
        success.append(0)
        failure.append(0)
        other.append(0)
        unknown_15.append(1)

bank_df['success'] = success
bank_df['failure'] = failure
bank_df['other'] = other
bank_df['unknown_15'] = unknown_15
bank_df = bank_df.drop('15',axis=1)

values_16 = bank_df['16']
label = []

for value in values_16:
    if value == '"no"':
        label.append(0)
    else:
        label.append(1)

bank_df['label'] = label
bank_df = bank_df.drop('16',axis=1)

# %%
bank_df['0'] = Normalize(bank_df['0'])
bank_df['5'] = Normalize(bank_df['5'])
bank_df['9'] = Normalize(bank_df['9'])
bank_df['11'] = Normalize(bank_df['11'])
bank_df['12'] = Normalize(bank_df['12'])
bank_df['13'] = Normalize(bank_df['13'])
bank_df['14'] = Normalize(bank_df['14'])

# %%
bank_df['0'] = pd.qcut(bank_df['0'], q=50, duplicates='drop')
bank_df['0'] = bank_df['0'].cat.codes
bank_df['0'] = bank_df['0'].astype(str)

bank_df['5'] = pd.qcut(bank_df['5'], q=50, duplicates='drop')
bank_df['5'] = bank_df['5'].cat.codes
bank_df['5'] = bank_df['5'].astype(str)

bank_df['11'] = pd.qcut(bank_df['11'], q=50, duplicates='drop')
bank_df['11'] = bank_df['11'].cat.codes
bank_df['11'] = bank_df['11'].astype(str)

bank_df['13'] = pd.qcut(bank_df['13'], q=50, duplicates='drop')
bank_df['13'] = bank_df['13'].cat.codes
bank_df['13'] = bank_df['13'].astype(str)

# %%
bank_df_x = bank_df.drop('label',axis=1)
bank_df_y = bank_df['label']
info_gain = mutual_info_classif(bank_df_x, bank_df_y,random_state=42)
for i in range(len(bank_df_x.columns)):
    print("Feature: " + bank_df_x.columns[i] + " --- Importance: " + str(info_gain[i]))
num_feature_swap = len(info_gain) * 0.25
print("Num Feature Rotate: " + str(num_feature_swap))
print(np.sort(info_gain))

# %%
feature_swap = ['11', 'success', '13', 'unknown_15', 'unknown_8', 'celluar', '6', '14', '0', 'may', '9', '5']
# features = bank_df_x.columns
# for i in range(len(features)):
#     if features[i] == '5':
#         print(i)

# %%
bank_df_shullfe = bank_df.sample(frac=1).reset_index(drop=True)
eleven_before = bank_df_shullfe['11']
success_before = bank_df_shullfe['success']
thirteen_before = bank_df_shullfe['13']
unknown_15_before = bank_df_shullfe['unknown_15']
unknown_8_before = bank_df_shullfe['unknown_8']
celluar_before = bank_df_shullfe['celluar']
six_before = bank_df_shullfe['6']
fourteen_before = bank_df_shullfe['14']
zero_before = bank_df_shullfe['0']
may_before = bank_df_shullfe['may']
nine_before = bank_df_shullfe['9']
five_before = bank_df_shullfe['5']
label = bank_df_shullfe['label']
Change_Point = round(len(label) / 2)

# %%
new_eleven = []
new_success = []
new_thirteen = []
new_unknown_15 = []
new_unknown_8 = []
new_celluar = []
new_six = []
new_fourteen = []
new_zero = []
new_may = []
new_nine = []
new_five = []

for i in range(len(label)):
    if i <= Change_Point:
        new_eleven.append(eleven_before[i])
        new_success.append(success_before[i])
        new_thirteen.append(thirteen_before[i])
        new_unknown_15.append(unknown_15_before[i])
        new_unknown_8.append(unknown_8_before[i])
        new_celluar.append(celluar_before[i])
        new_six.append(six_before[i])
        new_fourteen.append(fourteen_before[i])
        new_zero.append(zero_before[i])
        new_may.append(may_before[i])
        new_nine.append(nine_before[i])
        new_five.append(five_before[i])
    else:
        if label[i] == 0:
            new_eleven.append(success_before[i])
            new_success.append(thirteen_before[i])
            new_thirteen.append(unknown_15_before[i])
            new_unknown_15.append(unknown_8_before[i])
            new_unknown_8.append(celluar_before[i])
            new_celluar.append(six_before[i])
            new_six.append(fourteen_before[i])
            new_fourteen.append(zero_before[i])
            new_zero.append(may_before[i])
            new_may.append(nine_before[i])
            new_nine.append(five_before[i])
            new_five.append(eleven_before[i])
        else:
            new_eleven.append(eleven_before[i])
            new_success.append(success_before[i])
            new_thirteen.append(thirteen_before[i])
            new_unknown_15.append(unknown_15_before[i])
            new_unknown_8.append(unknown_8_before[i])
            new_celluar.append(celluar_before[i])
            new_six.append(six_before[i])
            new_fourteen.append(fourteen_before[i])
            new_zero.append(zero_before[i])
            new_may.append(may_before[i])
            new_nine.append(nine_before[i])
            new_five.append(five_before[i])
            
bank_df_shullfe['11'] = new_eleven
bank_df_shullfe['success'] = new_success
bank_df_shullfe['13'] = new_thirteen
bank_df_shullfe['unknown_15'] = new_unknown_15
bank_df_shullfe['unknown_8'] = new_unknown_8
bank_df_shullfe['celluar'] = new_celluar
bank_df_shullfe['6'] = new_six
bank_df_shullfe['14'] = new_fourteen
bank_df_shullfe['0'] = new_zero
bank_df_shullfe['may'] = new_may
bank_df_shullfe['9'] = new_nine
bank_df_shullfe['5'] = new_five

bank_df_shullfe.to_csv('feature_drift_2_bank.csv')

# %% [markdown]
# # Adult

# %%
adult_df = pd.read_csv('Datasets_original/original_adult.csv', header=None)
adult_df.columns = adult_df.columns.astype(str)

# %%
work_class_values = adult_df['1']

private = []
self_emp_not_inc = []
self_emp_inc = []
federal_gov = []
local_gov = []
state_gov = []
without_pay = []
never_worked = []

for i in range(len(work_class_values)):
    if work_class_values[i] == ' Private':
        private.append(1)
        self_emp_not_inc.append(0)
        self_emp_inc.append(0)
        federal_gov.append(0)
        local_gov.append(0)
        state_gov.append(0)
        without_pay.append(0)
        never_worked.append(0)
    elif work_class_values[i] == ' Self-emp-not-inc':
        private.append(0)
        self_emp_not_inc.append(1)
        self_emp_inc.append(0)
        federal_gov.append(0)
        local_gov.append(0)
        state_gov.append(0)
        without_pay.append(0)
        never_worked.append(0)
    elif work_class_values[i] == ' Self-emp-inc':
        private.append(0)
        self_emp_not_inc.append(0)
        self_emp_inc.append(1)
        federal_gov.append(0)
        local_gov.append(0)
        state_gov.append(0)
        without_pay.append(0)
        never_worked.append(0)
    elif work_class_values[i] == ' Federal-gov':
        private.append(0)
        self_emp_not_inc.append(0)
        self_emp_inc.append(0)
        federal_gov.append(1)
        local_gov.append(0)
        state_gov.append(0)
        without_pay.append(0)
        never_worked.append(0)
    elif work_class_values[i] == ' Local-gov':
        private.append(0)
        self_emp_not_inc.append(0)
        self_emp_inc.append(0)
        federal_gov.append(0)
        local_gov.append(1)
        state_gov.append(0)
        without_pay.append(0)
        never_worked.append(0)
    elif work_class_values[i] == ' State-gov':
        private.append(0)
        self_emp_not_inc.append(0)
        self_emp_inc.append(0)
        federal_gov.append(0)
        local_gov.append(0)
        state_gov.append(1)
        without_pay.append(0)
        never_worked.append(0)
    elif work_class_values[i] == ' Without-pay':
        private.append(0)
        self_emp_not_inc.append(0)
        self_emp_inc.append(0)
        federal_gov.append(0)
        local_gov.append(0)
        state_gov.append(0)
        without_pay.append(1)
        never_worked.append(0)
    elif work_class_values[i] == ' Never-worked':
        private.append(0)
        self_emp_not_inc.append(0)
        self_emp_inc.append(0)
        federal_gov.append(0)
        local_gov.append(0)
        state_gov.append(0)
        without_pay.append(0)
        never_worked.append(1)
    else:
        private.append(1)
        self_emp_not_inc.append(0)
        self_emp_inc.append(0)
        federal_gov.append(0)
        local_gov.append(0)
        state_gov.append(0)
        without_pay.append(0)
        never_worked.append(0)
        
adult_df['private'] = private
adult_df['self_emp_not_inc'] = self_emp_not_inc
adult_df['self_emp_inc'] = self_emp_inc
adult_df['federal_gov'] = federal_gov
adult_df['local_gov'] = local_gov
adult_df['state_gov'] = state_gov
adult_df['without_pay'] = without_pay
adult_df['never_worked'] = never_worked
adult_df = adult_df.drop('1', axis=1)

education_values = adult_df['3']

bachelors = []
some_college = []
eleven = []
hs_grad = []
prof_school = []
assoc_acdm = []
assoc_voc = []
nine = []
seven_eight = []
twelve = []
masters = []
one_four = []
ten = []
doctorate = []
five_six = []
preschool = []

for i in range(len(education_values)):
    if education_values[i] == ' Bachelors':
        bachelors.append(1)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' Some-college':
        bachelors.append(0)
        some_college.append(1)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' 11th':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(1)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' HS-grad':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(1)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' Prof-school':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(1)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' Assoc-acdm':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(1)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' Assoc-voc':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(1)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' 9th':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(1)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' 7th-8th':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(1)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' 12th':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(1)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' Masters':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(1)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' 1st-4th':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(1)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' 10th':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(1)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' Doctorate':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(1)
        five_six.append(0)
        preschool.append(0)
    elif education_values[i] == ' 5th-6th':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(1)
        preschool.append(0)
    elif education_values[i] == ' Preschool':
        bachelors.append(0)
        some_college.append(0)
        eleven.append(0)
        hs_grad.append(0)
        prof_school.append(0)
        assoc_acdm.append(0)
        assoc_voc.append(0)
        nine.append(0)
        seven_eight.append(0)
        twelve.append(0)
        masters.append(0)
        one_four.append(0)
        ten.append(0)
        doctorate.append(0)
        five_six.append(0)
        preschool.append(1)

adult_df['bachelors'] = bachelors
adult_df['some_college'] = some_college
adult_df['11th'] = eleven
adult_df['hs_grad'] = hs_grad
adult_df['prof_school'] = prof_school
adult_df['assoc_acdm'] = assoc_acdm
adult_df['assoc_voc'] = assoc_voc
adult_df['9th'] = nine
adult_df['7th_8th'] = seven_eight
adult_df['12th'] = twelve
adult_df['masters'] = masters
adult_df['1st_4th'] = one_four
adult_df['10th'] = ten
adult_df['doctorate'] = doctorate
adult_df['5th_6th'] = five_six
adult_df['preschool'] = preschool
adult_df = adult_df.drop('3',axis=1)

marital_status_values = adult_df['5']

married_civ_spouse = []
divorced = []
never_married = []
separated = []
widowed = []
married_spouse_absent = []
married_AF_spouse = []

for i in range(len(marital_status_values)):
    if marital_status_values[i] == ' Married-civ-spouse':
        married_civ_spouse.append(1)
        divorced.append(0)
        never_married.append(0)
        separated.append(0)
        widowed.append(0)
        married_spouse_absent.append(0)
        married_AF_spouse.append(0)
    elif marital_status_values[i] == ' Divorced':
        married_civ_spouse.append(0)
        divorced.append(1)
        never_married.append(0)
        separated.append(0)
        widowed.append(0)
        married_spouse_absent.append(0)
        married_AF_spouse.append(0)
    elif marital_status_values[i] == ' Never-married':
        married_civ_spouse.append(0)
        divorced.append(0)
        never_married.append(1)
        separated.append(0)
        widowed.append(0)
        married_spouse_absent.append(0)
        married_AF_spouse.append(0)
    elif marital_status_values[i] == ' Separated':
        married_civ_spouse.append(0)
        divorced.append(0)
        never_married.append(0)
        separated.append(1)
        widowed.append(0)
        married_spouse_absent.append(0)
        married_AF_spouse.append(0)
    elif marital_status_values[i] == ' Widowed':
        married_civ_spouse.append(0)
        divorced.append(0)
        never_married.append(0)
        separated.append(0)
        widowed.append(1)
        married_spouse_absent.append(0)
        married_AF_spouse.append(0)
    elif marital_status_values[i] == ' Married-spouse-absent':
        married_civ_spouse.append(0)
        divorced.append(0)
        never_married.append(0)
        separated.append(0)
        widowed.append(0)
        married_spouse_absent.append(1)
        married_AF_spouse.append(0)
    elif marital_status_values[i] == ' Married-AF-spouse':
        married_civ_spouse.append(0)
        divorced.append(0)
        never_married.append(0)
        separated.append(0)
        widowed.append(0)
        married_spouse_absent.append(0)
        married_AF_spouse.append(1)

adult_df['married_civ_spouse'] = married_civ_spouse
adult_df['divorced'] = divorced
adult_df['never_married'] = never_married
adult_df['separated'] = separated
adult_df['widowed'] = widowed
adult_df['married_spouse_absent'] = married_spouse_absent
adult_df['married_AF_spouse'] = married_AF_spouse
adult_df = adult_df.drop('5',axis=1)

occupation_values = adult_df['6']

tech_support = []
craft_repair = []
other_service = []
sales = []
exec_managerial = []
prof_specialty = []
handlers_cleaners = []
machine_op_inspct = []
adm_clerical = []
farming_fishing = []
transport_moving = []
priv_house_serv = []
protective_serv = []
armed_forces = []

for i in range(len(occupation_values)):
    if occupation_values[i] == ' Tech-support':
        tech_support.append(1)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Craft-repair':
        tech_support.append(0)
        craft_repair.append(1)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Other-service':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(1)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Sales':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(1)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Exec-managerial':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(1)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Prof-specialty':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(1)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Handlers-cleaners':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(1)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Machine-op-inspct':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(1)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Adm-clerical':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(1)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Farming-fishing':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(1)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Transport-moving':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(1)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Priv-house-serv':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(1)
        protective_serv.append(0)
        armed_forces.append(0)
    elif occupation_values[i] == ' Protective-serv':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(1)
        armed_forces.append(0)
    elif occupation_values[i] == ' Armed-Forces':
        tech_support.append(0)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(1)
    elif occupation_values[i] == ' ?':
        tech_support.append(1)
        craft_repair.append(0)
        other_service.append(0)
        sales.append(0)
        exec_managerial.append(0)
        prof_specialty.append(0)
        handlers_cleaners.append(0)
        machine_op_inspct.append(0)
        adm_clerical.append(0)
        farming_fishing.append(0)
        transport_moving.append(0)
        priv_house_serv.append(0)
        protective_serv.append(0)
        armed_forces.append(0)
        
adult_df['tech_support'] = tech_support
adult_df['craft_repair'] = craft_repair
adult_df['other_service'] = other_service
adult_df['sales'] = sales
adult_df['exec_managerial'] = exec_managerial
adult_df['prof_specialty'] = prof_specialty
adult_df['handlers_cleaners'] = handlers_cleaners
adult_df['machine_op_inspct'] = machine_op_inspct
adult_df['adm_clerical'] = adm_clerical
adult_df['farming_fishing'] = farming_fishing
adult_df['transport_moving'] = transport_moving
adult_df['priv_house_serv'] = priv_house_serv
adult_df['protective_serv'] = protective_serv
adult_df['armed_forces'] = armed_forces
adult_df = adult_df.drop('6', axis=1)

relationship_values = adult_df['7']

wife = []
own_child = []
husband = []
not_in_family = []
other_relative = []
unmarried = []

for i in range(len(relationship_values)):
    if relationship_values[i] == ' Wife':
        wife.append(1)
        own_child.append(0)
        husband.append(0)
        not_in_family.append(0)
        other_relative.append(0)
        unmarried.append(0)
    elif relationship_values[i] == ' Own-child':
        wife.append(0)
        own_child.append(1)
        husband.append(0)
        not_in_family.append(0)
        other_relative.append(0)
        unmarried.append(0)
    elif relationship_values[i] == ' Husband':
        wife.append(0)
        own_child.append(0)
        husband.append(1)
        not_in_family.append(0)
        other_relative.append(0)
        unmarried.append(0)
    elif relationship_values[i] == ' Not-in-family':
        wife.append(0)
        own_child.append(0)
        husband.append(0)
        not_in_family.append(1)
        other_relative.append(0)
        unmarried.append(0)
    elif relationship_values[i] == ' Other-relative':
        wife.append(0)
        own_child.append(0)
        husband.append(0)
        not_in_family.append(0)
        other_relative.append(1)
        unmarried.append(0)
    elif relationship_values[i] == ' Unmarried':
        wife.append(0)
        own_child.append(0)
        husband.append(0)
        not_in_family.append(0)
        other_relative.append(0)
        unmarried.append(1)
        
adult_df['wife'] = wife
adult_df['own_child'] = own_child
adult_df['husband'] = husband
adult_df['not_in_family'] = not_in_family
adult_df['other_relative'] = other_relative
adult_df['unmarried'] = unmarried
adult_df = adult_df.drop('7', axis=1)

race_values = adult_df['8']

white = []
asian_pac_islander = []
amer_indian_eskimo = []
black = []
other = []

for i in range(len(race_values)):
    if race_values[i] == ' White':
        white.append(1)
        asian_pac_islander.append(0)
        amer_indian_eskimo.append(0)
        black.append(0)
        other.append(0)
    elif race_values[i] == ' Asian-Pac-Islander':
        white.append(0)
        asian_pac_islander.append(1)
        amer_indian_eskimo.append(0)
        black.append(0)
        other.append(0)
    elif race_values[i] == ' Amer-Indian-Eskimo':
        white.append(0)
        asian_pac_islander.append(0)
        amer_indian_eskimo.append(1)
        black.append(0)
        other.append(0)
    elif race_values[i] == ' Black':
        white.append(0)
        asian_pac_islander.append(0)
        amer_indian_eskimo.append(0)
        black.append(1)
        other.append(0)
    elif race_values[i] == ' Other':
        white.append(0)
        asian_pac_islander.append(0)
        amer_indian_eskimo.append(0)
        black.append(0)
        other.append(1)

adult_df['white'] = white
adult_df['asian_pac_islander'] = asian_pac_islander
adult_df['amer_indian_eskimo'] = amer_indian_eskimo
adult_df['black'] = black
adult_df['other'] = other
adult_df = adult_df.drop('8', axis=1)

gender_values = adult_df['9']
male = []
female = []

for i in range(len(gender_values)):
    if gender_values[i] == ' Male':
        male.append(1)
        female.append(0)
    elif gender_values[i] == ' Female':
        male.append(0)
        female.append(1)
        
adult_df['male'] = male
adult_df['female'] = female
adult_df = adult_df.drop('9', axis=1)

country_values = adult_df['13']

new_country_values = []

for i in range(len(country_values)):
    if country_values[i] == ' United-States':
        new_country_values.append(1)
    else:
        new_country_values.append(0)
        
adult_df['country'] = new_country_values
adult_df = adult_df.drop('13', axis = 1)

label_values = adult_df['14']
new_label = []

l1 = 0
l2 = 0
for i in range(len(label_values)):
    if label_values[i] == ' >50K':
        new_label.append(1)
        l1 += 1
    elif label_values[i] == ' >50K.':
        new_label.append(1)
        l2 += 1
    else:
        new_label.append(0)

adult_df['label'] = new_label
adult_df = adult_df.drop('14', axis=1)

# %%
adult_df['0'] = Normalize(adult_df['0'])
adult_df['2'] = Normalize(adult_df['2'])
adult_df['4'] = Normalize(adult_df['4'])
adult_df['10'] = Normalize(adult_df['10'])
adult_df['11'] = Normalize(adult_df['11'])
adult_df['12'] = Normalize(adult_df['12'])

# %%
adult_df['0'] = pd.qcut(adult_df['0'], q=50, duplicates='drop')
adult_df['0'] = adult_df['0'].cat.codes
adult_df['0'] = adult_df['0'].astype(str)

adult_df['2'] = pd.qcut(adult_df['2'], q=50, duplicates='drop')
adult_df['2'] = adult_df['2'].cat.codes
adult_df['2'] = adult_df['2'].astype(str)

adult_df['10'] = pd.qcut(adult_df['10'], q=50, duplicates='drop')
adult_df['10'] = adult_df['10'].cat.codes
adult_df['10'] = adult_df['10'].astype(str)

adult_df['11'] = pd.qcut(adult_df['11'], q=50, duplicates='drop')
adult_df['11'] = adult_df['11'].cat.codes
adult_df['11'] = adult_df['11'].astype(str)

adult_df['12'] = pd.qcut(adult_df['12'], q=50, duplicates='drop')
adult_df['12'] = adult_df['12'].cat.codes
adult_df['12'] = adult_df['12'].astype(str)

# %%
adult_df_x = adult_df.drop('label',axis=1)
adult_df_y = adult_df['label']
info_gain = mutual_info_classif(adult_df_x, adult_df_y,random_state=42)
for i in range(len(adult_df_x.columns)):
    print("Feature: " + adult_df_x.columns[i] + " --- Importance: " + str(info_gain[i]))
num_feature_swap = len(info_gain) * 0.25
print("Num Feature Rotate: " + str(num_feature_swap))
print(np.sort(info_gain))

# %%
feature_swap = ['married_civ_spouse', 'husband', '0', 'never_married', '4', '10', '12', 'own_child', 'male', 'female', 
                'exec_managerial', 'not_in_family', 'other_service', 'bachelors', 'prof_specialty', 'unmarried']

features = adult_df_x.columns
for i in range(len(features)):
    if features[i] == 'unmarried':
        print(i)

# %%
adult_df_shuffle = adult_df.sample(frac=1).reset_index(drop=True)

married_civ_spouse_before = adult_df_shuffle['married_civ_spouse']
husband_before = adult_df_shuffle['husband']
zero_before = adult_df_shuffle['0']
never_married_before = adult_df_shuffle['never_married']
four_before = adult_df_shuffle['4']
ten_before = adult_df_shuffle['10']
twelve_before = adult_df_shuffle['12']
own_child_before = adult_df_shuffle['own_child']
male_before = adult_df_shuffle['male']
female_before = adult_df_shuffle['female']
exec_managerial_before = adult_df_shuffle['exec_managerial']
not_in_family_before = adult_df_shuffle['not_in_family']
other_service_before = adult_df_shuffle['other_service']
bachelors_before = adult_df_shuffle['bachelors']
prof_specialty_before = adult_df_shuffle['prof_specialty']
unmarried_before = adult_df_shuffle['unmarried']
label = adult_df_shuffle['label']
Change_Point = round(len(label) / 2)

# %%
new_married_civ_spouse = []
new_husband = []
new_zero = []
new_never_married = []
new_four = []
new_ten = []
new_twelve = []
new_own_child = []
new_male = []
new_female = []
new_exec_managerial = []
new_not_in_family = []
new_other_service = []
new_bachelors = []
new_prof_specialty = []
new_unmarried = []

for i in range(len(married_civ_spouse_before)):
    if i <= Change_Point:
        new_married_civ_spouse.append(married_civ_spouse_before[i])
        new_husband.append(husband_before[i])
        new_zero.append(zero_before[i])
        new_never_married.append(never_married_before[i])
        new_four.append(four_before[i])
        new_ten.append(ten_before[i])
        new_twelve.append(twelve_before[i])
        new_own_child.append(own_child_before[i])
        new_male.append(male_before[i])
        new_female.append(female_before[i])
        new_exec_managerial.append(exec_managerial_before[i])
        new_not_in_family.append(not_in_family_before[i])
        new_other_service.append(other_service_before[i])
        new_bachelors.append(bachelors_before[i])
        new_prof_specialty.append(prof_specialty_before[i])
        new_unmarried.append(unmarried_before[i])
    else:
        if label[i] == 0:
            new_married_civ_spouse.append(husband_before[i])
            new_husband.append(zero_before[i])
            new_zero.append(never_married_before[i])
            new_never_married.append(four_before[i])
            new_four.append(ten_before[i])
            new_ten.append(twelve_before[i])
            new_twelve.append(own_child_before[i])
            new_own_child.append(male_before[i])
            new_male.append(female_before[i])
            new_female.append(exec_managerial_before[i])
            new_exec_managerial.append(not_in_family_before[i])
            new_not_in_family.append(other_service_before[i])
            new_other_service.append(bachelors_before[i])
            new_bachelors.append(prof_specialty_before[i])
            new_prof_specialty.append(unmarried_before[i])
            new_unmarried.append(married_civ_spouse_before[i])
        else:
            new_married_civ_spouse.append(married_civ_spouse_before[i])
            new_husband.append(husband_before[i])
            new_zero.append(zero_before[i])
            new_never_married.append(never_married_before[i])
            new_four.append(four_before[i])
            new_ten.append(ten_before[i])
            new_twelve.append(twelve_before[i])
            new_own_child.append(own_child_before[i])
            new_male.append(male_before[i])
            new_female.append(female_before[i])
            new_exec_managerial.append(exec_managerial_before[i])
            new_not_in_family.append(not_in_family_before[i])
            new_other_service.append(other_service_before[i])
            new_bachelors.append(bachelors_before[i])
            new_prof_specialty.append(prof_specialty_before[i])
            new_unmarried.append(unmarried_before[i])
            
adult_df_shuffle['married_civ_spouse'] = new_married_civ_spouse
adult_df_shuffle['husband'] = new_husband
adult_df_shuffle['0'] = new_zero
adult_df_shuffle['never_married'] = new_never_married
adult_df_shuffle['4'] = new_four
adult_df_shuffle['10'] = new_ten
adult_df_shuffle['12'] = new_twelve
adult_df_shuffle['own_child'] = new_own_child
adult_df_shuffle['male'] = new_male
adult_df_shuffle['female'] = new_female
adult_df_shuffle['exec_managerial'] = new_exec_managerial
adult_df_shuffle['not_in_family'] = new_not_in_family
adult_df_shuffle['other_service'] = new_other_service
adult_df_shuffle['bachelors'] = new_bachelors
adult_df_shuffle['prof_specialty'] = new_prof_specialty
adult_df_shuffle['unmarried'] = new_unmarried

adult_df_shuffle.to_csv('Feature_Drift_Detection_Datasets/feature_drift_1_adult.csv')

# %% [markdown]
# # Credit

# %%
credit_df = pd.read_csv('Datasets_original/original_credit.csv')

# %%
sex_values = credit_df['SEX']
new_sex_values = []
for i in range(len(sex_values)):
    if sex_values[i] == 1:
        new_sex_values.append(1)
    if sex_values[i] == 2:
        new_sex_values.append(0)
credit_df['SEX'] = new_sex_values
credit_df['SEX'] = credit_df['SEX'].astype('int')

education_values = credit_df['EDUCATION']
graduate_school = []
university = []
high_school = []
others = []
for i in range(len(education_values)):
    if education_values[i] == 1:
        graduate_school.append(1)
        university.append(0)
        high_school.append(0)
        others.append(0)
    elif education_values[i] == 2:
        graduate_school.append(0)
        university.append(1)
        high_school.append(0)
        others.append(0)
    elif education_values[i] == 3:
        graduate_school.append(0)
        university.append(0)
        high_school.append(1)
        others.append(0)
    else:
        graduate_school.append(0)
        university.append(0)
        high_school.append(0)
        others.append(1)
credit_df = credit_df.drop('EDUCATION', axis=1)
credit_df['education_graduate_school'] = graduate_school
credit_df['education_university'] = university
credit_df['education_high_school'] = high_school
credit_df['education_others'] = others

marriage_values = credit_df['MARRIAGE']
new_marriage_values = []
for i in range(len(marriage_values)):
    if marriage_values[i] == 1:
        new_marriage_values.append(1)
    else:
        new_marriage_values.append(0)
credit_df['MARRIAGE'] = new_marriage_values

# %%
credit_df['LIMIT_BAL'] = Normalize(credit_df['LIMIT_BAL'])
credit_df['AGE'] = Normalize(credit_df['AGE'])
credit_df['PAY_0'] = Normalize(credit_df['PAY_0'])
credit_df['PAY_2'] = Normalize(credit_df['PAY_2'])
credit_df['PAY_3'] = Normalize(credit_df['PAY_3'])
credit_df['PAY_4'] = Normalize(credit_df['PAY_4'])
credit_df['PAY_5'] = Normalize(credit_df['PAY_5'])
credit_df['PAY_6'] = Normalize(credit_df['PAY_6'])
credit_df['BILL_AMT1'] = Normalize(credit_df['BILL_AMT1'])
credit_df['BILL_AMT2'] = Normalize(credit_df['BILL_AMT2'])
credit_df['BILL_AMT3'] = Normalize(credit_df['BILL_AMT3'])
credit_df['BILL_AMT4'] = Normalize(credit_df['BILL_AMT4'])
credit_df['BILL_AMT5'] = Normalize(credit_df['BILL_AMT5'])
credit_df['BILL_AMT6'] = Normalize(credit_df['BILL_AMT6'])
credit_df['PAY_AMT1'] = Normalize(credit_df['PAY_AMT1'])
credit_df['PAY_AMT2'] = Normalize(credit_df['PAY_AMT2'])
credit_df['PAY_AMT3'] = Normalize(credit_df['PAY_AMT3'])
credit_df['PAY_AMT4'] = Normalize(credit_df['PAY_AMT4'])
credit_df['PAY_AMT5'] = Normalize(credit_df['PAY_AMT5'])
credit_df['PAY_AMT6'] = Normalize(credit_df['PAY_AMT6'])

# %%
credit_df['LIMIT_BAL'] = pd.qcut(credit_df['LIMIT_BAL'], q=38, duplicates='drop')
credit_df['LIMIT_BAL'] = credit_df['LIMIT_BAL'].cat.codes
credit_df['LIMIT_BAL'] = credit_df['LIMIT_BAL'].astype(str)

credit_df['AGE'] = pd.qcut(credit_df['AGE'], q=38, duplicates='drop')
credit_df['AGE'] = credit_df['AGE'].cat.codes
credit_df['AGE'] = credit_df['AGE'].astype(str)

credit_df['BILL_AMT1'] = pd.qcut(credit_df['BILL_AMT1'], q=38, duplicates='drop')
credit_df['BILL_AMT1'] = credit_df['BILL_AMT1'].cat.codes
credit_df['BILL_AMT1'] = credit_df['BILL_AMT1'].astype(str)

credit_df['BILL_AMT2'] = pd.qcut(credit_df['BILL_AMT2'], q=38, duplicates='drop')
credit_df['BILL_AMT2'] = credit_df['BILL_AMT2'].cat.codes
credit_df['BILL_AMT2'] = credit_df['BILL_AMT2'].astype(str)

credit_df['BILL_AMT3'] = pd.qcut(credit_df['BILL_AMT3'], q=38, duplicates='drop')
credit_df['BILL_AMT3'] = credit_df['BILL_AMT3'].cat.codes
credit_df['BILL_AMT3'] = credit_df['BILL_AMT3'].astype(str)

credit_df['BILL_AMT4'] = pd.qcut(credit_df['BILL_AMT4'], q=38, duplicates='drop')
credit_df['BILL_AMT4'] = credit_df['BILL_AMT4'].cat.codes
credit_df['BILL_AMT4'] = credit_df['BILL_AMT4'].astype(str)

credit_df['BILL_AMT5'] = pd.qcut(credit_df['BILL_AMT5'], q=38, duplicates='drop')
credit_df['BILL_AMT5'] = credit_df['BILL_AMT5'].cat.codes
credit_df['BILL_AMT5'] = credit_df['BILL_AMT5'].astype(str)

credit_df['BILL_AMT6'] = pd.qcut(credit_df['BILL_AMT6'], q=38, duplicates='drop')
credit_df['BILL_AMT6'] = credit_df['BILL_AMT6'].cat.codes
credit_df['BILL_AMT6'] = credit_df['BILL_AMT6'].astype(str)

credit_df['PAY_AMT1'] = pd.qcut(credit_df['PAY_AMT1'], q=38, duplicates='drop')
credit_df['PAY_AMT1'] = credit_df['PAY_AMT1'].cat.codes
credit_df['PAY_AMT1'] = credit_df['PAY_AMT1'].astype(str)

credit_df['PAY_AMT2'] = pd.qcut(credit_df['PAY_AMT2'], q=38, duplicates='drop')
credit_df['PAY_AMT2'] = credit_df['PAY_AMT2'].cat.codes
credit_df['PAY_AMT2'] = credit_df['PAY_AMT2'].astype(str)

credit_df['PAY_AMT3'] = pd.qcut(credit_df['PAY_AMT3'], q=38, duplicates='drop')
credit_df['PAY_AMT3'] = credit_df['PAY_AMT3'].cat.codes
credit_df['PAY_AMT3'] = credit_df['PAY_AMT3'].astype(str)

credit_df['PAY_AMT4'] = pd.qcut(credit_df['PAY_AMT4'], q=38, duplicates='drop')
credit_df['PAY_AMT4'] = credit_df['PAY_AMT4'].cat.codes
credit_df['PAY_AMT4'] = credit_df['PAY_AMT4'].astype(str)

credit_df['PAY_AMT5'] = pd.qcut(credit_df['PAY_AMT5'], q=38, duplicates='drop')
credit_df['PAY_AMT5'] = credit_df['PAY_AMT5'].cat.codes
credit_df['PAY_AMT5'] = credit_df['PAY_AMT5'].astype(str)

credit_df['PAY_AMT6'] = pd.qcut(credit_df['PAY_AMT6'], q=38, duplicates='drop')
credit_df['PAY_AMT6'] = credit_df['PAY_AMT6'].cat.codes
credit_df['PAY_AMT6'] = credit_df['PAY_AMT6'].astype(str)

# %%
credit_df_x = credit_df.drop('default payment next month', axis=1)
credit_df_y = credit_df['default payment next month']
info_gain = mutual_info_classif(credit_df_x, credit_df_y,random_state=42)
for i in range(len(credit_df_x.columns)):
    print("Feature: " + credit_df_x.columns[i] + " --- Importance: " + str(info_gain[i]))
num_feature_swap = len(info_gain) * 0.25
print("Num Feature Rotate: " + str(num_feature_swap))
print(np.sort(info_gain))

# %%
feature_swap = ['PAY_0', 'PAY_2', 'PAY_4', 'PAY_3', 'PAY_5', 'PAY_6']

features = credit_df_x.columns
for i in range(len(features)):
    if features[i] == 'PAY_6':
        print(i)

# %%
credit_df_shuffle = credit_df.sample(frac=1).reset_index(drop=True)

PAY_0_before = credit_df_shuffle['PAY_0']
PAY_2_before = credit_df_shuffle['PAY_2']
PAY_4_before = credit_df_shuffle['PAY_4']
PAY_3_before = credit_df_shuffle['PAY_3']
PAY_5_before = credit_df_shuffle['PAY_5']
PAY_6_before = credit_df_shuffle['PAY_6']
label = credit_df_shuffle['default payment next month']
Change_Point = round(len(PAY_0_before) / 2)

# %%
new_pay_0 = []
new_pay_2 = []
new_pay_4 = []
new_pay_3 = []
new_pay_5 = []
new_pay_6 = []

for i in range(len(PAY_0_before)):
    if i <= Change_Point:
        new_pay_0.append(PAY_0_before[i])
        new_pay_2.append(PAY_2_before[i])
        new_pay_4.append(PAY_4_before[i])
        new_pay_3.append(PAY_3_before[i])
        new_pay_5.append(PAY_5_before[i])
        new_pay_6.append(PAY_6_before[i])
    else:
        if label[i] == 0:
            new_pay_0.append(PAY_2_before[i])
            new_pay_2.append(PAY_4_before[i])
            new_pay_4.append(PAY_3_before[i])
            new_pay_3.append(PAY_5_before[i])
            new_pay_5.append(PAY_6_before[i])
            new_pay_6.append(PAY_0_before[i])
        else:
            new_pay_0.append(PAY_0_before[i])
            new_pay_2.append(PAY_2_before[i])
            new_pay_4.append(PAY_4_before[i])
            new_pay_3.append(PAY_3_before[i])
            new_pay_5.append(PAY_5_before[i])
            new_pay_6.append(PAY_6_before[i])
            
credit_df_shuffle['PAY_0'] = new_pay_0
credit_df_shuffle['PAY_2'] = new_pay_2
credit_df_shuffle['PAY_4'] = new_pay_4
credit_df_shuffle['PAY_3'] = new_pay_3
credit_df_shuffle['PAY_5'] = new_pay_5
credit_df_shuffle['PAY_6'] = new_pay_6

credit_df_shuffle['label'] = credit_df_shuffle['default payment next month']
credit_df_shuffle = credit_df_shuffle.drop('default payment next month', axis=1)
credit_df_shuffle.to_csv('Feature_Drift_Detection_Datasets/feature_drift_3_credit.csv')

# %% [markdown]
# # Gamma

# %%
with open('Datasets_original/magic04.data') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    dataframe_list = []
    columns_name = ['fLength','fWidth','fSize','fConc','fConc1','fAsym','fM3Long','fM3Trans','fAlpha','fDist','class']
    for row in csv_reader:
        dataframe_list.append(row)
    gamma_df = pd.DataFrame(dataframe_list, columns=columns_name)

# %%
class_value = gamma_df['class']
new_class_value = []
for i in range(len(class_value)):
    if class_value[i] == 'g':
        new_class_value.append(1)
    else:
        new_class_value.append(0)
gamma_df['class'] = new_class_value

# %%
gamma_df['fLength'] = gamma_df['fLength'].astype(float)
gamma_df['fWidth'] = gamma_df['fWidth'].astype(float)
gamma_df['fSize'] = gamma_df['fSize'].astype(float)
gamma_df['fConc'] = gamma_df['fConc'].astype(float)
gamma_df['fConc1'] = gamma_df['fConc1'].astype(float)
gamma_df['fAsym'] = gamma_df['fAsym'].astype(float)
gamma_df['fM3Long'] = gamma_df['fM3Long'].astype(float)
gamma_df['fM3Trans'] = gamma_df['fM3Trans'].astype(float)
gamma_df['fAlpha'] = gamma_df['fAlpha'].astype(float)
gamma_df['fDist'] = gamma_df['fDist'].astype(float)

gamma_df['fLength'] = Normalize(gamma_df['fLength'])
gamma_df['fWidth'] = Normalize(gamma_df['fWidth'])
gamma_df['fSize'] = Normalize(gamma_df['fSize'])
gamma_df['fAsym'] = Normalize(gamma_df['fAsym'])
gamma_df['fM3Long'] = Normalize(gamma_df['fM3Long'])
gamma_df['fM3Trans'] = Normalize(gamma_df['fM3Trans'])
gamma_df['fAlpha'] = Normalize(gamma_df['fAlpha'])
gamma_df['fDist'] = Normalize(gamma_df['fDist'])

# %%
gamma_df['fLength'] = pd.qcut(gamma_df['fLength'], q=31, duplicates='drop')
gamma_df['fLength'] = gamma_df['fLength'].cat.codes
gamma_df['fLength'] = gamma_df['fLength'].astype(str)

gamma_df['fWidth'] = pd.qcut(gamma_df['fWidth'], q=31, duplicates='drop')
gamma_df['fWidth'] = gamma_df['fWidth'].cat.codes
gamma_df['fWidth'] = gamma_df['fWidth'].astype(str)

gamma_df['fSize'] = pd.qcut(gamma_df['fSize'], q=31, duplicates='drop')
gamma_df['fSize'] = gamma_df['fSize'].cat.codes
gamma_df['fSize'] = gamma_df['fSize'].astype(str)

gamma_df['fAsym'] = pd.qcut(gamma_df['fAsym'], q=31, duplicates='drop')
gamma_df['fAsym'] = gamma_df['fAsym'].cat.codes
gamma_df['fAsym'] = gamma_df['fAsym'].astype(str)

gamma_df['fM3Long'] = pd.qcut(gamma_df['fM3Long'], q=31, duplicates='drop')
gamma_df['fM3Long'] = gamma_df['fM3Long'].cat.codes
gamma_df['fM3Long'] = gamma_df['fM3Long'].astype(str)

gamma_df['fM3Trans'] = pd.qcut(gamma_df['fM3Trans'], q=31, duplicates='drop')
gamma_df['fM3Trans'] = gamma_df['fM3Trans'].cat.codes
gamma_df['fM3Trans'] = gamma_df['fM3Trans'].astype(str)

gamma_df['fAlpha'] = pd.qcut(gamma_df['fAlpha'], q=31, duplicates='drop')
gamma_df['fAlpha'] = gamma_df['fAlpha'].cat.codes
gamma_df['fAlpha'] = gamma_df['fAlpha'].astype(str)

gamma_df['fDist'] = pd.qcut(gamma_df['fDist'], q=31, duplicates='drop')
gamma_df['fDist'] = gamma_df['fDist'].cat.codes
gamma_df['fDist'] = gamma_df['fDist'].astype(str)

# %%
gamma_df_x = gamma_df.drop('class',axis=1)
gamma_df_y = gamma_df['class']
info_gain = mutual_info_classif(gamma_df_x, gamma_df_y, random_state=42)
for i in range(len(gamma_df_x.columns)):
    print("Feature: " + gamma_df_x.columns[i] + " --- Importance: " + str(info_gain[i]))
num_feature_swap = len(info_gain) * 0.25
print("Num Feature Rotate: " + str(num_feature_swap))
print(np.sort(info_gain))

# %%
feature_swap = ['fAlpha', 'fWidth', 'fLength']

features = gamma_df_x.columns
for i in range(len(features)):
    if features[i] == 'fLength':
        print(i)

# %%
gamma_df_shuffle = gamma_df.sample(frac=1).reset_index(drop=True)
fAlpha_before = gamma_df_shuffle['fAlpha']
fWidth_before = gamma_df_shuffle['fWidth']
fLength_before = gamma_df_shuffle['fLength']
label = gamma_df_shuffle['class']
Change_Point = round(len(fAlpha_before) / 2)

# %%
new_fAlpha = []
new_fWidth = []
new_fLength = []

for i in range(len(fAlpha_before)):
    if i <= Change_Point:
        new_fAlpha.append(fAlpha_before[i])
        new_fWidth.append(fWidth_before[i])
        new_fLength.append(fLength_before[i])
    else:
        if label[i] == 0:
            new_fAlpha.append(fWidth_before[i])
            new_fWidth.append(fLength_before[i])
            new_fLength.append(fAlpha_before[i])
        else:
            new_fAlpha.append(fAlpha_before[i])
            new_fWidth.append(fWidth_before[i])
            new_fLength.append(fLength_before[i]) 

gamma_df_shuffle['fAlpha'] = new_fAlpha
gamma_df_shuffle['fWidth'] = new_fWidth
gamma_df_shuffle['fLength'] = new_fLength

gamma_df_shuffle.to_csv('Feature_Drift_Detection_Datasets/feature_drift_4_gamma.csv')
